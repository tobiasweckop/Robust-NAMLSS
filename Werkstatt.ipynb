# %% [markdown]
# ### NAMLSS Code & Helper Functions

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.distributions as dist

class NormalNAMLSS(nn.Module):
    def __init__(self, n_covariates, hidden_size=8, intercept=False):
        super(NormalNAMLSS, self).__init__()

        self.submodules = nn.ModuleList([
            nn.Sequential(
                nn.Linear(1, hidden_size),
                nn.Tanh(),
                nn.Linear(hidden_size, 2)
            ) for _ in range(n_covariates)
        ])

        self.use_intercept = intercept
        if self.use_intercept:
            self.intercept = nn.Parameter(torch.zeros(2))

    def forward(self, x):
        param_mat_list = [self.submodules[i](x[:, i:i + 1]) for i in range(x.shape[1])]
        x = torch.stack(param_mat_list, dim=1)
        mu_components = x[:, :, 0]
        sigma_components = F.softplus(x[:, :, 1])

        mu = torch.sum(mu_components, dim=1).unsqueeze(dim=1)
        sigma = torch.sum(sigma_components, dim=1).unsqueeze(dim=1)

        if self.use_intercept:
            mu = mu + self.intercept[0]
            sigma = sigma + F.softplus(self.intercept[1])

        return mu, sigma

    def nll_loss(self, mu, sigma, y_true, robustness_factor=None):
        normal_dist = dist.Normal(mu, sigma)
        log_likelihood = normal_dist.log_prob(y_true).mean()

        if robustness_factor is not None:
            log_likelihood = torch.log((1 + torch.exp(normal_dist.log_prob(y_true) + robustness_factor)) / (1 + torch.exp(robustness_factor))).mean() 

        nll = -log_likelihood
        return nll


    def fit(self, X_train, y_train, X_val=None, y_val=None, n_epochs=10000, lr=1e-3, weight_decay=0.0, 
            early_stopping_patience=10, robustness_factor=None):

        optimizer = torch.optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)

        best_val_loss = float('inf')
        patience_counter = 0

        for epoch in range(n_epochs):
            self.train()

            # Forward pass and loss computation
            mu, sigma = self.forward(X_train)
            train_loss = self.nll_loss(mu, sigma, y_train, robustness_factor)

            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()

            val_loss = None
            if X_val is not None and y_val is not None:
                self.eval()
                with torch.no_grad():
                    mu_val, sigma_val = self.forward(X_val)
                    val_loss = self.nll_loss(mu_val, sigma_val, y_val, robustness_factor).item()

                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    patience_counter = 0
                    best_model_state = self.state_dict()
                else:
                    patience_counter += 1

                if (patience_counter >= early_stopping_patience) and (epoch >= 1000):
                    print(f"Early stopping at epoch {epoch}. Best validation loss: {best_val_loss:.4f}")
                    self.load_state_dict(best_model_state)
                    break

            if epoch % 100 == 0 or val_loss is not None:
                print(f"Epoch {epoch} - Train Loss: {train_loss.item():.4f} - Val Loss: {val_loss:.4f}" if val_loss else f"Epoch {epoch} - Train Loss: {train_loss.item():.4f}")

        return self
    
    def predict(self, x):
        mu, sigma = self.forward(x)

        mu = mu.detach()
        sigma = sigma.detach()

        return mu, sigma
        

    def marginal_effects(self, x):
        with torch.no_grad():
            param_mat_list = [self.submodules[i](x[:, i:i + 1]) for i in range(x.shape[1])]
            x = torch.stack(param_mat_list, dim=1)
            mu_components = x[:, :, 0].detach().cpu().numpy()
            sigma_components = F.softplus(x[:, :, 1]).detach().cpu().numpy()
        return mu_components, sigma_components

# %%
def F1(X):
    return (2 * X + torch.sin(X * 2.5 * torch.pi)).squeeze()

def F2(X):
    return (3 - 3 * X ** 2).squeeze()

def F3(X):
    return (12 * (X - 0.5) ** 2).squeeze()

def S1(X):
    return torch.exp(-0.5 + 2 * X - 1.5 * X ** 2).squeeze()

def S2(X):
    return (1.2 - 1/2 * X).squeeze()

def S3(X):
    return (X/X).squeeze()

# %% [markdown]
# ### Simulation using 3 Covariates

# %%
import random
import numpy as np
import torch.distributions as dist
from sklearn.preprocessing import StandardScaler


def simulation_run():

    ########## Drawing Covariate Samples ##########
    n_train, n_val, n_test = 10000, 10000, 10000
    prop_corrupt = 0.1
    n_var = 3
    Uniform = dist.Uniform(0, 1)

    X_train = Uniform.sample(sample_shape = [n_train, n_var])
    X_val = Uniform.sample(sample_shape = [n_val, n_var])
    X_test = Uniform.sample(sample_shape = [n_test, n_var])

    ########## Training Dataset ##########
    F1_train = F1(X_train[:,0])
    F2_train = F2(X_train[:,1])
    F3_train = F3(X_train[:,2])

    S1_train = S1(X_train[:,0])
    S2_train = S2(X_train[:,1])
    S3_train = S3(X_train[:,2])

    y_train = torch.normal(mean = F1_train + F2_train + F3_train, std = S1_train + S2_train + S3_train)
    corrupted_train_indices = torch.tensor(random.sample(range(1, n_train), int(n_train * prop_corrupt)))
    y_train[corrupted_train_indices] = torch.normal(torch.ones(len(corrupted_train_indices)) * 15, torch.ones(len(corrupted_train_indices)) * 2) # TODO: Bessere Outlier
    y_train = y_train.view(n_train, 1)

    intact_train_indices = torch.ones(n_train, dtype=bool)
    intact_train_indices[corrupted_train_indices] = False

    ########## Validation Dataset ###########
    F1_val = F1(X_val[:,0])
    F2_val = F2(X_val[:,1])
    F3_val = F3(X_val[:,2])

    S1_val = S1(X_val[:,0])
    S2_val = S2(X_val[:,1])
    S3_val = S3(X_val[:,2])

    y_val =  + torch.normal(mean = F1_val + F2_val + F3_val, std = S1_val + S2_val + S3_val)
    corrupted_val_indices = torch.tensor(random.sample(range(1, n_val), int(n_val * prop_corrupt)))
    y_val[corrupted_val_indices] = torch.normal(torch.ones(len(corrupted_val_indices)) * 15, torch.ones(len(corrupted_val_indices)) * 2) # TODO: Bessere Outlier
    y_val = y_val.view(n_val, 1)

    ########## Testing Dataset ##########
    F1_test = F1(X_test[:,0])
    F2_test = F2(X_test[:,1])
    F3_test = F3(X_test[:,2])
    F_test = np.column_stack((F1_test, F2_test, F3_test))

    S1_test = S1(X_test[:,0])
    S2_test = S2(X_test[:,1])
    S3_test = S3(X_test[:,2])
    S_test = np.column_stack((S1_test, S2_test, S3_test))

    y_test = torch.normal(mean = F1_test + F2_test + F3_test, std = S1_test + S2_test + S3_test)
    corrupted_test_indices = torch.tensor(random.sample(range(1, n_test), int(n_test * prop_corrupt)))
    y_test[corrupted_test_indices] = torch.normal(torch.ones(len(corrupted_test_indices)) * 15, torch.ones(len(corrupted_test_indices)) * 2) # TODO: Bessere Outlier

    y_test = y_test.view(n_test, 1)
    
    ########## Scaling the Data ##########
    scaler = StandardScaler()
    scaler1, scaler2, scaler3 = StandardScaler(), StandardScaler(), StandardScaler()

    X_train_scaled = torch.tensor(scaler.fit_transform(X_train), dtype = torch.float32)
    X_val_scaled = torch.tensor(scaler.fit_transform(X_val), dtype = torch.float32)
    X_test_scaled = torch.tensor(scaler.fit_transform(X_test), dtype = torch.float32)

    y_train_scaled = torch.tensor(scaler1.fit_transform(y_train), dtype = torch.float32)
    y_val_scaled = torch.tensor(scaler2.fit_transform(y_val), dtype = torch.float32)
    y_test_scaled = torch.tensor(scaler3.fit_transform(y_test), dtype = torch.float32)

    ########## Training the Networks ##########
    nam = NormalNAMLSS(3)
    nam.fit(X_train_scaled, y_train_scaled, X_val_scaled, y_val_scaled, robustness_factor = None)

    robust_nam = NormalNAMLSS(3)
    robust_nam.fit(X_train_scaled, y_train_scaled, X_val_scaled, y_val_scaled, robustness_factor=torch.tensor(3))

    strict_nam = NormalNAMLSS(3)
    strict_nam.fit(X_train_scaled, y_train_scaled, X_val_scaled, y_val_scaled, robustness_factor=torch.tensor(1))

    ########## Predicting Parameters on Scaled Data ##########
    mu, sigma = nam.predict(X_test_scaled)
    rob_mu, rob_sigma = robust_nam.predict(X_test_scaled)
    strict_mu, strict_sigma = strict_nam.predict(X_test_scaled)

    mu_components, sigma_components = nam.marginal_effects(X_test_scaled)
    robust_mu_components, robust_sigma_components = robust_nam.marginal_effects(X_test_scaled)
    strict_mu_components, strict_sigma_components = strict_nam.marginal_effects(X_test_scaled)

    ########## Rescaling Predicted Parameters ##########
    mu = mu * scaler3.scale_ + scaler3.mean_
    rob_mu = rob_mu * scaler3.scale_ + scaler3.mean_
    strict_mu = strict_mu * scaler3.scale_ + scaler3.mean_

    sigma = sigma * scaler3.scale_
    rob_sigma = rob_sigma * scaler3.scale_
    strict_sigma = strict_sigma * scaler3.scale_

    mu_components = mu_components * scaler3.scale_ + scaler3.mean_
    robust_mu_components = robust_mu_components * scaler3.scale_ + scaler3.mean_
    strict_mu_components = strict_mu_components * scaler3.scale_ + scaler3.mean_

    sigma_components = sigma_components * scaler3.scale_
    robust_sigma_components = robust_sigma_components * scaler3.scale_
    strict_sigma_components = strict_sigma_components * scaler3.scale_

    ########## Return Dictionary with Relevant Information ##########
    run_result_dict = {
        "X_test": X_test,
        "y_test": y_test,
        "F_test":F_test,
        "S_test":S_test,
        "mu_components": mu_components,
        "robust_mu_components": robust_mu_components,
        "strict_mu_components": strict_mu_components,
        "sigma_components": sigma_components,
        "robust_sigma_components": robust_sigma_components,
        "strict_sigma_components": strict_sigma_components}
    
    return run_result_dict

# %%
def simulation(runs):
    result_list = [simulation_run() for _ in range(runs)]
    return result_list

# %%
import numpy as np
import pandas as pd

def get_mse(simulation_run_dict):

    F_test = simulation_run_dict["F_test"]
    mu_components = simulation_run_dict["mu_components"]
    robust_mu_components = simulation_run_dict["robust_mu_components"]
    strict_mu_components = simulation_run_dict["strict_mu_components"]

    S_test = simulation_run_dict["S_test"]
    sigma_components = simulation_run_dict["sigma_components"]
    robust_sigma_components = simulation_run_dict["robust_sigma_components"]
    strict_sigma_components = simulation_run_dict["strict_sigma_components"] 

    # Mu
    mean_mse_values = {
        "X1": [
            np.mean(((mu_components[:, 0] - mu_components[:, 0].mean()) - (F_test[:,0] - F_test[:,0].mean())) ** 2),
            np.mean(((robust_mu_components[:, 0] - robust_mu_components[:, 0].mean()) - (F_test[:,0] - F_test[:,0].mean())) ** 2),
            np.mean(((strict_mu_components[:, 0] - strict_mu_components[:, 0].mean()) - (F_test[:,0] - F_test[:,0].mean())) ** 2)
        ],
        "X2": [
            np.mean(((mu_components[:, 1] - mu_components[:, 1].mean()) - (F_test[:,1] - F_test[:,1].mean())) ** 2),
            np.mean(((robust_mu_components[:, 1] - robust_mu_components[:, 1].mean()) - (F_test[:,1] - F_test[:,1].mean())) ** 2),
            np.mean(((strict_mu_components[:, 1] - strict_mu_components[:, 1].mean()) - (F_test[:,1] - F_test[:,1].mean())) ** 2)
        ],
        "X3": [
            np.mean(((mu_components[:, 2] - mu_components[:, 2].mean()) - (F_test[:,2] - F_test[:,2].mean())) ** 2),
            np.mean(((robust_mu_components[:, 2] - robust_mu_components[:, 2].mean()) - (F_test[:,2] - F_test[:,2].mean())) ** 2),
            np.mean(((strict_mu_components[:, 2] - strict_mu_components[:, 2].mean()) - (F_test[:,2] - F_test[:,2].mean())) ** 2)
        ]
    }

    # Sigma
    sigma_mse_values = {
        "X1": [
            np.mean(((sigma_components[:, 0] - sigma_components[:, 0].mean()) - (S_test[:,0] - S_test[:,0].mean())) ** 2),
            np.mean(((robust_sigma_components[:, 0] - robust_sigma_components[:, 0].mean()) - (S_test[:,0] - S_test[:,0].mean())) ** 2),
            np.mean(((strict_sigma_components[:, 0] - strict_sigma_components[:, 0].mean()) - (S_test[:,0] - S_test[:,0].mean())) ** 2)
        ],
        "X2": [
            np.mean(((sigma_components[:, 1] - sigma_components[:, 1].mean()) - (S_test[:,1] - S_test[:,1].mean())) ** 2),
            np.mean(((robust_sigma_components[:, 1] - robust_sigma_components[:, 1].mean()) - (S_test[:,1] - S_test[:,1].mean())) ** 2),
            np.mean(((strict_sigma_components[:, 1] - strict_sigma_components[:, 1].mean()) - (S_test[:,1] - S_test[:,1].mean())) ** 2)
        ],
        "X3": [
            np.mean(((sigma_components[:, 2] - sigma_components[:, 2].mean()) - (S_test[:,2] - S_test[:,2].mean())) ** 2),
            np.mean(((robust_sigma_components[:, 2] - robust_sigma_components[:, 2].mean()) - (S_test[:,2] - S_test[:,2].mean())) ** 2),
            np.mean(((strict_sigma_components[:, 2] - strict_sigma_components[:, 2].mean()) - (S_test[:,2] - S_test[:,2].mean())) ** 2)
        ]
    }

    mean_mse_df = pd.DataFrame(mean_mse_values, index=["mu", "robust_mu", "strict_mu"]).round(5)
    sigma_mse_df = pd.DataFrame(sigma_mse_values, index=["sigma", "robust_sigma", "strict_sigma"]).round(5)

    return {"Mean_MSE":mean_mse_df,
            "Sigma_MSE":sigma_mse_df}

# %%
def simulation_mse_tables(simulation_runs):
    mean_mse_list = []
    sigma_mse_list = []
    
    for run_dict in simulation_runs:

        mse_results = get_mse(run_dict)
        
        mean_mse_list.append(mse_results["Mean_MSE"].values)
        sigma_mse_list.append(mse_results["Sigma_MSE"].values)
    
    mean_mse_array = np.array(mean_mse_list)  # Shape: (num_runs, 3, 3)
    sigma_mse_array = np.array(sigma_mse_list)

    # Compute averages across simulation runs
    mean_mse_avg = np.mean(mean_mse_array, axis = 0)
    sigma_mse_avg = np.mean(sigma_mse_array, axis = 0)

    # Convert back to DataFrame
    mean_mse_df = pd.DataFrame(mean_mse_avg, columns = ["X1", "X2", "X3"], index = ["mu", "robust_mu", "strict_mu"]).round(5)
    sigma_mse_df = pd.DataFrame(sigma_mse_avg, columns = ["X1", "X2", "X3"], index = ["sigma", "robust_sigma", "strict_sigma"]).round(5)

    return {"Mean_MSE_Avg": mean_mse_df, "Sigma_MSE_Avg": sigma_mse_df}

# %%
simulation_list = simulation(3)
# Out:
# Epoch 0 - Train Loss: 1.8072 - Val Loss: 1.8042
# Epoch 1 - Train Loss: 1.8033 - Val Loss: 1.8002
# Epoch 2 - Train Loss: 1.7993 - Val Loss: 1.7963
# Epoch 3 - Train Loss: 1.7954 - Val Loss: 1.7924
# Epoch 4 - Train Loss: 1.7915 - Val Loss: 1.7885
# Epoch 5 - Train Loss: 1.7877 - Val Loss: 1.7846
# Epoch 6 - Train Loss: 1.7838 - Val Loss: 1.7808
# Epoch 7 - Train Loss: 1.7800 - Val Loss: 1.7769
# Epoch 8 - Train Loss: 1.7762 - Val Loss: 1.7731
# Epoch 9 - Train Loss: 1.7725 - Val Loss: 1.7694
# Epoch 10 - Train Loss: 1.7687 - Val Loss: 1.7656
# Epoch 11 - Train Loss: 1.7650 - Val Loss: 1.7619
# Epoch 12 - Train Loss: 1.7613 - Val Loss: 1.7582
# Epoch 13 - Train Loss: 1.7577 - Val Loss: 1.7545
# Epoch 14 - Train Loss: 1.7540 - Val Loss: 1.7509
# Epoch 15 - Train Loss: 1.7504 - Val Loss: 1.7472
# Epoch 16 - Train Loss: 1.7468 - Val Loss: 1.7436
# Epoch 17 - Train Loss: 1.7432 - Val Loss: 1.7400
# Epoch 18 - Train Loss: 1.7396 - Val Loss: 1.7365
# Epoch 19 - Train Loss: 1.7361 - Val Loss: 1.7329
# Epoch 20 - Train Loss: 1.7326 - Val Loss: 1.7294
# Epoch 21 - Train Loss: 1.7291 - Val Loss: 1.7259
# Epoch 22 - Train Loss: 1.7256 - Val Loss: 1.7224
# Epoch 23 - Train Loss: 1.7221 - Val Loss: 1.7189
# Epoch 24 - Train Loss: 1.7187 - Val Loss: 1.7155
# Epoch 25 - Train Loss: 1.7153 - Val Loss: 1.7120
# Epoch 26 - Train Loss: 1.7119 - Val Loss: 1.7086
# Epoch 27 - Train Loss: 1.7085 - Val Loss: 1.7052
# Epoch 28 - Train Loss: 1.7051 - Val Loss: 1.7018
# Epoch 29 - Train Loss: 1.7017 - Val Loss: 1.6984
# Epoch 30 - Train Loss: 1.6984 - Val Loss: 1.6951
# Epoch 31 - Train Loss: 1.6951 - Val Loss: 1.6917
# Epoch 32 - Train Loss: 1.6917 - Val Loss: 1.6884
# Epoch 33 - Train Loss: 1.6884 - Val Loss: 1.6851
# Epoch 34 - Train Loss: 1.6851 - Val Loss: 1.6818
# Epoch 35 - Train Loss: 1.6819 - Val Loss: 1.6785
# Epoch 36 - Train Loss: 1.6786 - Val Loss: 1.6752
# Epoch 37 - Train Loss: 1.6753 - Val Loss: 1.6719
# Epoch 38 - Train Loss: 1.6721 - Val Loss: 1.6687
# Epoch 39 - Train Loss: 1.6689 - Val Loss: 1.6654
# Epoch 40 - Train Loss: 1.6656 - Val Loss: 1.6622
# Epoch 41 - Train Loss: 1.6624 - Val Loss: 1.6590
# Epoch 42 - Train Loss: 1.6592 - Val Loss: 1.6558
# Epoch 43 - Train Loss: 1.6560 - Val Loss: 1.6525
# Epoch 44 - Train Loss: 1.6528 - Val Loss: 1.6494
# Epoch 45 - Train Loss: 1.6497 - Val Loss: 1.6462
# Epoch 46 - Train Loss: 1.6465 - Val Loss: 1.6430
# Epoch 47 - Train Loss: 1.6434 - Val Loss: 1.6398
# Epoch 48 - Train Loss: 1.6402 - Val Loss: 1.6367
# Epoch 49 - Train Loss: 1.6371 - Val Loss: 1.6336
# Epoch 50 - Train Loss: 1.6340 - Val Loss: 1.6304
# Epoch 51 - Train Loss: 1.6309 - Val Loss: 1.6273
# Epoch 52 - Train Loss: 1.6278 - Val Loss: 1.6242
# Epoch 53 - Train Loss: 1.6247 - Val Loss: 1.6211
# Epoch 54 - Train Loss: 1.6216 - Val Loss: 1.6181
# Epoch 55 - Train Loss: 1.6186 - Val Loss: 1.6150
# Epoch 56 - Train Loss: 1.6156 - Val Loss: 1.6120
# Epoch 57 - Train Loss: 1.6125 - Val Loss: 1.6089
# Epoch 58 - Train Loss: 1.6095 - Val Loss: 1.6059
# Epoch 59 - Train Loss: 1.6065 - Val Loss: 1.6029
# Epoch 60 - Train Loss: 1.6035 - Val Loss: 1.5999
# Epoch 61 - Train Loss: 1.6006 - Val Loss: 1.5970
# Epoch 62 - Train Loss: 1.5976 - Val Loss: 1.5940
# Epoch 63 - Train Loss: 1.5947 - Val Loss: 1.5911
# Epoch 64 - Train Loss: 1.5918 - Val Loss: 1.5881
# Epoch 65 - Train Loss: 1.5889 - Val Loss: 1.5852
# Epoch 66 - Train Loss: 1.5860 - Val Loss: 1.5824
# Epoch 67 - Train Loss: 1.5831 - Val Loss: 1.5795
# Epoch 68 - Train Loss: 1.5802 - Val Loss: 1.5766
# Epoch 69 - Train Loss: 1.5774 - Val Loss: 1.5738
# Epoch 70 - Train Loss: 1.5746 - Val Loss: 1.5710
# Epoch 71 - Train Loss: 1.5718 - Val Loss: 1.5682
# Epoch 72 - Train Loss: 1.5690 - Val Loss: 1.5654
# Epoch 73 - Train Loss: 1.5662 - Val Loss: 1.5626
# Epoch 74 - Train Loss: 1.5635 - Val Loss: 1.5599
# Epoch 75 - Train Loss: 1.5607 - Val Loss: 1.5572
# Epoch 76 - Train Loss: 1.5580 - Val Loss: 1.5544
# Epoch 77 - Train Loss: 1.5553 - Val Loss: 1.5518
# Epoch 78 - Train Loss: 1.5527 - Val Loss: 1.5491
# Epoch 79 - Train Loss: 1.5500 - Val Loss: 1.5464
# Epoch 80 - Train Loss: 1.5474 - Val Loss: 1.5438
# Epoch 81 - Train Loss: 1.5448 - Val Loss: 1.5412
# Epoch 82 - Train Loss: 1.5422 - Val Loss: 1.5386
# Epoch 83 - Train Loss: 1.5396 - Val Loss: 1.5361
# Epoch 84 - Train Loss: 1.5370 - Val Loss: 1.5335
# Epoch 85 - Train Loss: 1.5345 - Val Loss: 1.5310
# Epoch 86 - Train Loss: 1.5320 - Val Loss: 1.5285
# Epoch 87 - Train Loss: 1.5295 - Val Loss: 1.5261
# Epoch 88 - Train Loss: 1.5270 - Val Loss: 1.5236
# Epoch 89 - Train Loss: 1.5246 - Val Loss: 1.5212
# Epoch 90 - Train Loss: 1.5222 - Val Loss: 1.5188
# Epoch 91 - Train Loss: 1.5198 - Val Loss: 1.5164
# Epoch 92 - Train Loss: 1.5174 - Val Loss: 1.5140
# Epoch 93 - Train Loss: 1.5151 - Val Loss: 1.5117
# Epoch 94 - Train Loss: 1.5128 - Val Loss: 1.5094
# Epoch 95 - Train Loss: 1.5105 - Val Loss: 1.5071
# Epoch 96 - Train Loss: 1.5082 - Val Loss: 1.5049
# Epoch 97 - Train Loss: 1.5059 - Val Loss: 1.5026
# Epoch 98 - Train Loss: 1.5037 - Val Loss: 1.5004
# Epoch 99 - Train Loss: 1.5015 - Val Loss: 1.4983
# Epoch 100 - Train Loss: 1.4993 - Val Loss: 1.4961
# Epoch 101 - Train Loss: 1.4972 - Val Loss: 1.4940
# Epoch 102 - Train Loss: 1.4950 - Val Loss: 1.4919
# Epoch 103 - Train Loss: 1.4929 - Val Loss: 1.4898
# Epoch 104 - Train Loss: 1.4909 - Val Loss: 1.4878
# Epoch 105 - Train Loss: 1.4888 - Val Loss: 1.4857
# Epoch 106 - Train Loss: 1.4868 - Val Loss: 1.4837
# Epoch 107 - Train Loss: 1.4848 - Val Loss: 1.4818
# Epoch 108 - Train Loss: 1.4828 - Val Loss: 1.4798
# Epoch 109 - Train Loss: 1.4809 - Val Loss: 1.4779
# Epoch 110 - Train Loss: 1.4790 - Val Loss: 1.4760
# Epoch 111 - Train Loss: 1.4771 - Val Loss: 1.4742
# Epoch 112 - Train Loss: 1.4752 - Val Loss: 1.4723
# Epoch 113 - Train Loss: 1.4734 - Val Loss: 1.4705
# Epoch 114 - Train Loss: 1.4716 - Val Loss: 1.4688
# Epoch 115 - Train Loss: 1.4698 - Val Loss: 1.4670
# Epoch 116 - Train Loss: 1.4681 - Val Loss: 1.4653
# Epoch 117 - Train Loss: 1.4663 - Val Loss: 1.4636
# Epoch 118 - Train Loss: 1.4646 - Val Loss: 1.4619
# Epoch 119 - Train Loss: 1.4630 - Val Loss: 1.4603
# Epoch 120 - Train Loss: 1.4613 - Val Loss: 1.4587
# Epoch 121 - Train Loss: 1.4597 - Val Loss: 1.4571
# Epoch 122 - Train Loss: 1.4581 - Val Loss: 1.4556
# Epoch 123 - Train Loss: 1.4566 - Val Loss: 1.4540
# Epoch 124 - Train Loss: 1.4550 - Val Loss: 1.4525
# Epoch 125 - Train Loss: 1.4535 - Val Loss: 1.4511
# Epoch 126 - Train Loss: 1.4520 - Val Loss: 1.4496
# Epoch 127 - Train Loss: 1.4506 - Val Loss: 1.4482
# Epoch 128 - Train Loss: 1.4492 - Val Loss: 1.4468
# Epoch 129 - Train Loss: 1.4478 - Val Loss: 1.4455
# Epoch 130 - Train Loss: 1.4464 - Val Loss: 1.4441
# Epoch 131 - Train Loss: 1.4451 - Val Loss: 1.4428
# Epoch 132 - Train Loss: 1.4437 - Val Loss: 1.4416
# Epoch 133 - Train Loss: 1.4425 - Val Loss: 1.4403
# Epoch 134 - Train Loss: 1.4412 - Val Loss: 1.4391
# Epoch 135 - Train Loss: 1.4400 - Val Loss: 1.4379
# Epoch 136 - Train Loss: 1.4387 - Val Loss: 1.4367
# Epoch 137 - Train Loss: 1.4376 - Val Loss: 1.4356
# Epoch 138 - Train Loss: 1.4364 - Val Loss: 1.4344
# Epoch 139 - Train Loss: 1.4353 - Val Loss: 1.4333
# Epoch 140 - Train Loss: 1.4342 - Val Loss: 1.4323
# Epoch 141 - Train Loss: 1.4331 - Val Loss: 1.4312
# Epoch 142 - Train Loss: 1.4320 - Val Loss: 1.4302
# Epoch 143 - Train Loss: 1.4310 - Val Loss: 1.4292
# Epoch 144 - Train Loss: 1.4300 - Val Loss: 1.4282
# Epoch 145 - Train Loss: 1.4290 - Val Loss: 1.4273
# Epoch 146 - Train Loss: 1.4280 - Val Loss: 1.4264
# Epoch 147 - Train Loss: 1.4271 - Val Loss: 1.4255
# Epoch 148 - Train Loss: 1.4261 - Val Loss: 1.4246
# Epoch 149 - Train Loss: 1.4252 - Val Loss: 1.4237
# Epoch 150 - Train Loss: 1.4244 - Val Loss: 1.4229
# Epoch 151 - Train Loss: 1.4235 - Val Loss: 1.4221
# Epoch 152 - Train Loss: 1.4227 - Val Loss: 1.4213
# Epoch 153 - Train Loss: 1.4219 - Val Loss: 1.4205
# Epoch 154 - Train Loss: 1.4211 - Val Loss: 1.4198
# Epoch 155 - Train Loss: 1.4203 - Val Loss: 1.4190
# Epoch 156 - Train Loss: 1.4196 - Val Loss: 1.4183
# Epoch 157 - Train Loss: 1.4189 - Val Loss: 1.4176
# Epoch 158 - Train Loss: 1.4182 - Val Loss: 1.4170
# Epoch 159 - Train Loss: 1.4175 - Val Loss: 1.4163
# Epoch 160 - Train Loss: 1.4168 - Val Loss: 1.4157
# Epoch 161 - Train Loss: 1.4161 - Val Loss: 1.4151
# Epoch 162 - Train Loss: 1.4155 - Val Loss: 1.4145
# Epoch 163 - Train Loss: 1.4149 - Val Loss: 1.4139
# Epoch 164 - Train Loss: 1.4143 - Val Loss: 1.4133
# Epoch 165 - Train Loss: 1.4137 - Val Loss: 1.4128
# Epoch 166 - Train Loss: 1.4132 - Val Loss: 1.4123
# Epoch 167 - Train Loss: 1.4126 - Val Loss: 1.4117
# Epoch 168 - Train Loss: 1.4121 - Val Loss: 1.4112
# Epoch 169 - Train Loss: 1.4116 - Val Loss: 1.4108
# Epoch 170 - Train Loss: 1.4111 - Val Loss: 1.4103
# Epoch 171 - Train Loss: 1.4106 - Val Loss: 1.4098
# Epoch 172 - Train Loss: 1.4101 - Val Loss: 1.4094
# Epoch 173 - Train Loss: 1.4096 - Val Loss: 1.4090
# Epoch 174 - Train Loss: 1.4092 - Val Loss: 1.4086
# Epoch 175 - Train Loss: 1.4088 - Val Loss: 1.4082
# Epoch 176 - Train Loss: 1.4083 - Val Loss: 1.4078
# Epoch 177 - Train Loss: 1.4079 - Val Loss: 1.4074
# Epoch 178 - Train Loss: 1.4075 - Val Loss: 1.4070
# Epoch 179 - Train Loss: 1.4072 - Val Loss: 1.4067
# Epoch 180 - Train Loss: 1.4068 - Val Loss: 1.4063
# Epoch 181 - Train Loss: 1.4064 - Val Loss: 1.4060
# Epoch 182 - Train Loss: 1.4061 - Val Loss: 1.4057
# Epoch 183 - Train Loss: 1.4057 - Val Loss: 1.4054
# Epoch 184 - Train Loss: 1.4054 - Val Loss: 1.4051
# Epoch 185 - Train Loss: 1.4051 - Val Loss: 1.4048
# Epoch 186 - Train Loss: 1.4048 - Val Loss: 1.4045
# Epoch 187 - Train Loss: 1.4045 - Val Loss: 1.4042
# Epoch 188 - Train Loss: 1.4042 - Val Loss: 1.4040
# Epoch 189 - Train Loss: 1.4039 - Val Loss: 1.4037
# Epoch 190 - Train Loss: 1.4036 - Val Loss: 1.4034
# Epoch 191 - Train Loss: 1.4034 - Val Loss: 1.4032
# Epoch 192 - Train Loss: 1.4031 - Val Loss: 1.4030
# Epoch 193 - Train Loss: 1.4028 - Val Loss: 1.4027
# Epoch 194 - Train Loss: 1.4026 - Val Loss: 1.4025
# Epoch 195 - Train Loss: 1.4024 - Val Loss: 1.4023
# Epoch 196 - Train Loss: 1.4021 - Val Loss: 1.4021
# Epoch 197 - Train Loss: 1.4019 - Val Loss: 1.4019
# Epoch 198 - Train Loss: 1.4017 - Val Loss: 1.4017
# Epoch 199 - Train Loss: 1.4015 - Val Loss: 1.4015
# Epoch 200 - Train Loss: 1.4013 - Val Loss: 1.4013
# Epoch 201 - Train Loss: 1.4011 - Val Loss: 1.4011
# Epoch 202 - Train Loss: 1.4009 - Val Loss: 1.4010
# Epoch 203 - Train Loss: 1.4007 - Val Loss: 1.4008
# Epoch 204 - Train Loss: 1.4005 - Val Loss: 1.4006
# Epoch 205 - Train Loss: 1.4003 - Val Loss: 1.4005
# Epoch 206 - Train Loss: 1.4001 - Val Loss: 1.4003
# Epoch 207 - Train Loss: 1.4000 - Val Loss: 1.4001
# Epoch 208 - Train Loss: 1.3998 - Val Loss: 1.4000
# Epoch 209 - Train Loss: 1.3996 - Val Loss: 1.3998
# Epoch 210 - Train Loss: 1.3995 - Val Loss: 1.3997
# Epoch 211 - Train Loss: 1.3993 - Val Loss: 1.3996
# Epoch 212 - Train Loss: 1.3992 - Val Loss: 1.3994
# Epoch 213 - Train Loss: 1.3990 - Val Loss: 1.3993
# Epoch 214 - Train Loss: 1.3989 - Val Loss: 1.3992
# Epoch 215 - Train Loss: 1.3987 - Val Loss: 1.3990
# Epoch 216 - Train Loss: 1.3986 - Val Loss: 1.3989
# Epoch 217 - Train Loss: 1.3984 - Val Loss: 1.3988
# Epoch 218 - Train Loss: 1.3983 - Val Loss: 1.3987
# Epoch 219 - Train Loss: 1.3982 - Val Loss: 1.3985
# Epoch 220 - Train Loss: 1.3980 - Val Loss: 1.3984
# Epoch 221 - Train Loss: 1.3979 - Val Loss: 1.3983
# Epoch 222 - Train Loss: 1.3978 - Val Loss: 1.3982
# Epoch 223 - Train Loss: 1.3977 - Val Loss: 1.3981
# Epoch 224 - Train Loss: 1.3976 - Val Loss: 1.3980
# Epoch 225 - Train Loss: 1.3974 - Val Loss: 1.3979
# Epoch 226 - Train Loss: 1.3973 - Val Loss: 1.3978
# Epoch 227 - Train Loss: 1.3972 - Val Loss: 1.3977
# Epoch 228 - Train Loss: 1.3971 - Val Loss: 1.3976
# Epoch 229 - Train Loss: 1.3970 - Val Loss: 1.3975
# Epoch 230 - Train Loss: 1.3969 - Val Loss: 1.3974
# Epoch 231 - Train Loss: 1.3968 - Val Loss: 1.3973
# Epoch 232 - Train Loss: 1.3967 - Val Loss: 1.3972
# Epoch 233 - Train Loss: 1.3966 - Val Loss: 1.3971
# Epoch 234 - Train Loss: 1.3965 - Val Loss: 1.3970
# Epoch 235 - Train Loss: 1.3964 - Val Loss: 1.3969
# Epoch 236 - Train Loss: 1.3963 - Val Loss: 1.3968
# Epoch 237 - Train Loss: 1.3962 - Val Loss: 1.3968
# Epoch 238 - Train Loss: 1.3961 - Val Loss: 1.3967
# Epoch 239 - Train Loss: 1.3960 - Val Loss: 1.3966
# Epoch 240 - Train Loss: 1.3959 - Val Loss: 1.3965
# Epoch 241 - Train Loss: 1.3958 - Val Loss: 1.3964
# Epoch 242 - Train Loss: 1.3957 - Val Loss: 1.3963
# Epoch 243 - Train Loss: 1.3956 - Val Loss: 1.3962
# Epoch 244 - Train Loss: 1.3955 - Val Loss: 1.3962
# Epoch 245 - Train Loss: 1.3954 - Val Loss: 1.3961
# Epoch 246 - Train Loss: 1.3953 - Val Loss: 1.3960
# Epoch 247 - Train Loss: 1.3952 - Val Loss: 1.3959
# Epoch 248 - Train Loss: 1.3952 - Val Loss: 1.3959
# Epoch 249 - Train Loss: 1.3951 - Val Loss: 1.3958
# Epoch 250 - Train Loss: 1.3950 - Val Loss: 1.3957
# Epoch 251 - Train Loss: 1.3949 - Val Loss: 1.3956
# Epoch 252 - Train Loss: 1.3948 - Val Loss: 1.3955
# Epoch 253 - Train Loss: 1.3947 - Val Loss: 1.3955
# Epoch 254 - Train Loss: 1.3947 - Val Loss: 1.3954
# Epoch 255 - Train Loss: 1.3946 - Val Loss: 1.3953
# Epoch 256 - Train Loss: 1.3945 - Val Loss: 1.3952
# Epoch 257 - Train Loss: 1.3944 - Val Loss: 1.3952
# Epoch 258 - Train Loss: 1.3943 - Val Loss: 1.3951
# Epoch 259 - Train Loss: 1.3942 - Val Loss: 1.3950
# Epoch 260 - Train Loss: 1.3942 - Val Loss: 1.3950
# Epoch 261 - Train Loss: 1.3941 - Val Loss: 1.3949
# Epoch 262 - Train Loss: 1.3940 - Val Loss: 1.3948
# Epoch 263 - Train Loss: 1.3939 - Val Loss: 1.3947
# Epoch 264 - Train Loss: 1.3939 - Val Loss: 1.3947
# Epoch 265 - Train Loss: 1.3938 - Val Loss: 1.3946
# Epoch 266 - Train Loss: 1.3937 - Val Loss: 1.3945
# Epoch 267 - Train Loss: 1.3936 - Val Loss: 1.3945
# Epoch 268 - Train Loss: 1.3935 - Val Loss: 1.3944
# Epoch 269 - Train Loss: 1.3935 - Val Loss: 1.3943
# Epoch 270 - Train Loss: 1.3934 - Val Loss: 1.3943
# Epoch 271 - Train Loss: 1.3933 - Val Loss: 1.3942
# Epoch 272 - Train Loss: 1.3932 - Val Loss: 1.3941
# Epoch 273 - Train Loss: 1.3932 - Val Loss: 1.3941
# Epoch 274 - Train Loss: 1.3931 - Val Loss: 1.3940
# Epoch 275 - Train Loss: 1.3930 - Val Loss: 1.3939
# Epoch 276 - Train Loss: 1.3929 - Val Loss: 1.3939
# Epoch 277 - Train Loss: 1.3929 - Val Loss: 1.3938
# Epoch 278 - Train Loss: 1.3928 - Val Loss: 1.3937
# Epoch 279 - Train Loss: 1.3927 - Val Loss: 1.3937
# Epoch 280 - Train Loss: 1.3927 - Val Loss: 1.3936
# Epoch 281 - Train Loss: 1.3926 - Val Loss: 1.3935
# Epoch 282 - Train Loss: 1.3925 - Val Loss: 1.3935
# Epoch 283 - Train Loss: 1.3924 - Val Loss: 1.3934
# Epoch 284 - Train Loss: 1.3924 - Val Loss: 1.3933
# Epoch 285 - Train Loss: 1.3923 - Val Loss: 1.3933
# Epoch 286 - Train Loss: 1.3922 - Val Loss: 1.3932
# Epoch 287 - Train Loss: 1.3922 - Val Loss: 1.3931
# Epoch 288 - Train Loss: 1.3921 - Val Loss: 1.3931
# Epoch 289 - Train Loss: 1.3920 - Val Loss: 1.3930
# Epoch 290 - Train Loss: 1.3920 - Val Loss: 1.3929
# Epoch 291 - Train Loss: 1.3919 - Val Loss: 1.3929
# Epoch 292 - Train Loss: 1.3918 - Val Loss: 1.3928
# Epoch 293 - Train Loss: 1.3917 - Val Loss: 1.3928
# Epoch 294 - Train Loss: 1.3917 - Val Loss: 1.3927
# Epoch 295 - Train Loss: 1.3916 - Val Loss: 1.3926
# Epoch 296 - Train Loss: 1.3915 - Val Loss: 1.3926
# Epoch 297 - Train Loss: 1.3915 - Val Loss: 1.3925
# Epoch 298 - Train Loss: 1.3914 - Val Loss: 1.3924
# Epoch 299 - Train Loss: 1.3913 - Val Loss: 1.3924
# Epoch 300 - Train Loss: 1.3913 - Val Loss: 1.3923
# Epoch 301 - Train Loss: 1.3912 - Val Loss: 1.3923
# Epoch 302 - Train Loss: 1.3911 - Val Loss: 1.3922
# Epoch 303 - Train Loss: 1.3911 - Val Loss: 1.3921
# Epoch 304 - Train Loss: 1.3910 - Val Loss: 1.3921
# Epoch 305 - Train Loss: 1.3909 - Val Loss: 1.3920
# Epoch 306 - Train Loss: 1.3909 - Val Loss: 1.3920
# Epoch 307 - Train Loss: 1.3908 - Val Loss: 1.3919
# Epoch 308 - Train Loss: 1.3907 - Val Loss: 1.3918
# Epoch 309 - Train Loss: 1.3907 - Val Loss: 1.3918
# Epoch 310 - Train Loss: 1.3906 - Val Loss: 1.3917
# Epoch 311 - Train Loss: 1.3905 - Val Loss: 1.3917
# Epoch 312 - Train Loss: 1.3905 - Val Loss: 1.3916
# Epoch 313 - Train Loss: 1.3904 - Val Loss: 1.3915
# Epoch 314 - Train Loss: 1.3903 - Val Loss: 1.3915
# Epoch 315 - Train Loss: 1.3903 - Val Loss: 1.3914
# Epoch 316 - Train Loss: 1.3902 - Val Loss: 1.3914
# Epoch 317 - Train Loss: 1.3902 - Val Loss: 1.3913
# Epoch 318 - Train Loss: 1.3901 - Val Loss: 1.3912
# Epoch 319 - Train Loss: 1.3900 - Val Loss: 1.3912
# Epoch 320 - Train Loss: 1.3900 - Val Loss: 1.3911
# Epoch 321 - Train Loss: 1.3899 - Val Loss: 1.3911
# Epoch 322 - Train Loss: 1.3898 - Val Loss: 1.3910
# Epoch 323 - Train Loss: 1.3898 - Val Loss: 1.3910
# Epoch 324 - Train Loss: 1.3897 - Val Loss: 1.3909
# Epoch 325 - Train Loss: 1.3896 - Val Loss: 1.3908
# Epoch 326 - Train Loss: 1.3896 - Val Loss: 1.3908
# Epoch 327 - Train Loss: 1.3895 - Val Loss: 1.3907
# Epoch 328 - Train Loss: 1.3895 - Val Loss: 1.3907
# Epoch 329 - Train Loss: 1.3894 - Val Loss: 1.3906
# Epoch 330 - Train Loss: 1.3893 - Val Loss: 1.3906
# Epoch 331 - Train Loss: 1.3893 - Val Loss: 1.3905
# Epoch 332 - Train Loss: 1.3892 - Val Loss: 1.3904
# Epoch 333 - Train Loss: 1.3892 - Val Loss: 1.3904
# Epoch 334 - Train Loss: 1.3891 - Val Loss: 1.3903
# Epoch 335 - Train Loss: 1.3890 - Val Loss: 1.3903
# Epoch 336 - Train Loss: 1.3890 - Val Loss: 1.3902
# Epoch 337 - Train Loss: 1.3889 - Val Loss: 1.3902
# Epoch 338 - Train Loss: 1.3888 - Val Loss: 1.3901
# Epoch 339 - Train Loss: 1.3888 - Val Loss: 1.3901
# Epoch 340 - Train Loss: 1.3887 - Val Loss: 1.3900
# Epoch 341 - Train Loss: 1.3887 - Val Loss: 1.3900
# Epoch 342 - Train Loss: 1.3886 - Val Loss: 1.3899
# Epoch 343 - Train Loss: 1.3886 - Val Loss: 1.3898
# Epoch 344 - Train Loss: 1.3885 - Val Loss: 1.3898
# Epoch 345 - Train Loss: 1.3884 - Val Loss: 1.3897
# Epoch 346 - Train Loss: 1.3884 - Val Loss: 1.3897
# Epoch 347 - Train Loss: 1.3883 - Val Loss: 1.3896
# Epoch 348 - Train Loss: 1.3883 - Val Loss: 1.3896
# Epoch 349 - Train Loss: 1.3882 - Val Loss: 1.3895
# Epoch 350 - Train Loss: 1.3881 - Val Loss: 1.3895
# Epoch 351 - Train Loss: 1.3881 - Val Loss: 1.3894
# Epoch 352 - Train Loss: 1.3880 - Val Loss: 1.3894
# Epoch 353 - Train Loss: 1.3880 - Val Loss: 1.3893
# Epoch 354 - Train Loss: 1.3879 - Val Loss: 1.3893
# Epoch 355 - Train Loss: 1.3879 - Val Loss: 1.3892
# Epoch 356 - Train Loss: 1.3878 - Val Loss: 1.3892
# Epoch 357 - Train Loss: 1.3877 - Val Loss: 1.3891
# Epoch 358 - Train Loss: 1.3877 - Val Loss: 1.3891
# Epoch 359 - Train Loss: 1.3876 - Val Loss: 1.3890
# Epoch 360 - Train Loss: 1.3876 - Val Loss: 1.3890
# Epoch 361 - Train Loss: 1.3875 - Val Loss: 1.3889
# Epoch 362 - Train Loss: 1.3875 - Val Loss: 1.3889
# Epoch 363 - Train Loss: 1.3874 - Val Loss: 1.3888
# Epoch 364 - Train Loss: 1.3873 - Val Loss: 1.3888
# Epoch 365 - Train Loss: 1.3873 - Val Loss: 1.3887
# Epoch 366 - Train Loss: 1.3872 - Val Loss: 1.3887
# Epoch 367 - Train Loss: 1.3872 - Val Loss: 1.3886
# Epoch 368 - Train Loss: 1.3871 - Val Loss: 1.3886
# Epoch 369 - Train Loss: 1.3871 - Val Loss: 1.3885
# Epoch 370 - Train Loss: 1.3870 - Val Loss: 1.3885
# Epoch 371 - Train Loss: 1.3870 - Val Loss: 1.3884
# Epoch 372 - Train Loss: 1.3869 - Val Loss: 1.3884
# Epoch 373 - Train Loss: 1.3869 - Val Loss: 1.3883
# Epoch 374 - Train Loss: 1.3868 - Val Loss: 1.3883
# Epoch 375 - Train Loss: 1.3868 - Val Loss: 1.3882
# Epoch 376 - Train Loss: 1.3867 - Val Loss: 1.3882
# Epoch 377 - Train Loss: 1.3866 - Val Loss: 1.3881
# Epoch 378 - Train Loss: 1.3866 - Val Loss: 1.3881
# Epoch 379 - Train Loss: 1.3865 - Val Loss: 1.3880
# Epoch 380 - Train Loss: 1.3865 - Val Loss: 1.3880
# Epoch 381 - Train Loss: 1.3864 - Val Loss: 1.3879
# Epoch 382 - Train Loss: 1.3864 - Val Loss: 1.3879
# Epoch 383 - Train Loss: 1.3863 - Val Loss: 1.3878
# Epoch 384 - Train Loss: 1.3863 - Val Loss: 1.3878
# Epoch 385 - Train Loss: 1.3862 - Val Loss: 1.3877
# Epoch 386 - Train Loss: 1.3862 - Val Loss: 1.3877
# Epoch 387 - Train Loss: 1.3861 - Val Loss: 1.3876
# Epoch 388 - Train Loss: 1.3861 - Val Loss: 1.3876
# Epoch 389 - Train Loss: 1.3860 - Val Loss: 1.3876
# Epoch 390 - Train Loss: 1.3860 - Val Loss: 1.3875
# Epoch 391 - Train Loss: 1.3859 - Val Loss: 1.3875
# Epoch 392 - Train Loss: 1.3859 - Val Loss: 1.3874
# Epoch 393 - Train Loss: 1.3858 - Val Loss: 1.3874
# Epoch 394 - Train Loss: 1.3858 - Val Loss: 1.3873
# Epoch 395 - Train Loss: 1.3857 - Val Loss: 1.3873
# Epoch 396 - Train Loss: 1.3857 - Val Loss: 1.3872
# Epoch 397 - Train Loss: 1.3856 - Val Loss: 1.3872
# Epoch 398 - Train Loss: 1.3856 - Val Loss: 1.3871
# Epoch 399 - Train Loss: 1.3855 - Val Loss: 1.3871
# Epoch 400 - Train Loss: 1.3855 - Val Loss: 1.3871
# Epoch 401 - Train Loss: 1.3854 - Val Loss: 1.3870
# Epoch 402 - Train Loss: 1.3854 - Val Loss: 1.3870
# Epoch 403 - Train Loss: 1.3853 - Val Loss: 1.3869
# Epoch 404 - Train Loss: 1.3853 - Val Loss: 1.3869
# Epoch 405 - Train Loss: 1.3852 - Val Loss: 1.3868
# Epoch 406 - Train Loss: 1.3852 - Val Loss: 1.3868
# Epoch 407 - Train Loss: 1.3851 - Val Loss: 1.3868
# Epoch 408 - Train Loss: 1.3851 - Val Loss: 1.3867
# Epoch 409 - Train Loss: 1.3850 - Val Loss: 1.3867
# Epoch 410 - Train Loss: 1.3850 - Val Loss: 1.3866
# Epoch 411 - Train Loss: 1.3849 - Val Loss: 1.3866
# Epoch 412 - Train Loss: 1.3849 - Val Loss: 1.3865
# Epoch 413 - Train Loss: 1.3849 - Val Loss: 1.3865
# Epoch 414 - Train Loss: 1.3848 - Val Loss: 1.3865
# Epoch 415 - Train Loss: 1.3848 - Val Loss: 1.3864
# Epoch 416 - Train Loss: 1.3847 - Val Loss: 1.3864
# Epoch 417 - Train Loss: 1.3847 - Val Loss: 1.3863
# Epoch 418 - Train Loss: 1.3846 - Val Loss: 1.3863
# Epoch 419 - Train Loss: 1.3846 - Val Loss: 1.3863
# Epoch 420 - Train Loss: 1.3845 - Val Loss: 1.3862
# Epoch 421 - Train Loss: 1.3845 - Val Loss: 1.3862
# Epoch 422 - Train Loss: 1.3844 - Val Loss: 1.3861
# Epoch 423 - Train Loss: 1.3844 - Val Loss: 1.3861
# Epoch 424 - Train Loss: 1.3844 - Val Loss: 1.3861
# Epoch 425 - Train Loss: 1.3843 - Val Loss: 1.3860
# Epoch 426 - Train Loss: 1.3843 - Val Loss: 1.3860
# Epoch 427 - Train Loss: 1.3842 - Val Loss: 1.3859
# Epoch 428 - Train Loss: 1.3842 - Val Loss: 1.3859
# Epoch 429 - Train Loss: 1.3841 - Val Loss: 1.3859
# Epoch 430 - Train Loss: 1.3841 - Val Loss: 1.3858
# Epoch 431 - Train Loss: 1.3840 - Val Loss: 1.3858
# Epoch 432 - Train Loss: 1.3840 - Val Loss: 1.3857
# Epoch 433 - Train Loss: 1.3840 - Val Loss: 1.3857
# Epoch 434 - Train Loss: 1.3839 - Val Loss: 1.3857
# Epoch 435 - Train Loss: 1.3839 - Val Loss: 1.3856
# Epoch 436 - Train Loss: 1.3838 - Val Loss: 1.3856
# Epoch 437 - Train Loss: 1.3838 - Val Loss: 1.3855
# Epoch 438 - Train Loss: 1.3837 - Val Loss: 1.3855
# Epoch 439 - Train Loss: 1.3837 - Val Loss: 1.3855
# Epoch 440 - Train Loss: 1.3837 - Val Loss: 1.3854
# Epoch 441 - Train Loss: 1.3836 - Val Loss: 1.3854
# Epoch 442 - Train Loss: 1.3836 - Val Loss: 1.3854
# Epoch 443 - Train Loss: 1.3835 - Val Loss: 1.3853
# Epoch 444 - Train Loss: 1.3835 - Val Loss: 1.3853
# Epoch 445 - Train Loss: 1.3835 - Val Loss: 1.3852
# Epoch 446 - Train Loss: 1.3834 - Val Loss: 1.3852
# Epoch 447 - Train Loss: 1.3834 - Val Loss: 1.3852
# Epoch 448 - Train Loss: 1.3833 - Val Loss: 1.3851
# Epoch 449 - Train Loss: 1.3833 - Val Loss: 1.3851
# Epoch 450 - Train Loss: 1.3833 - Val Loss: 1.3851
# Epoch 451 - Train Loss: 1.3832 - Val Loss: 1.3850
# Epoch 452 - Train Loss: 1.3832 - Val Loss: 1.3850
# Epoch 453 - Train Loss: 1.3831 - Val Loss: 1.3850
# Epoch 454 - Train Loss: 1.3831 - Val Loss: 1.3849
# Epoch 455 - Train Loss: 1.3831 - Val Loss: 1.3849
# Epoch 456 - Train Loss: 1.3830 - Val Loss: 1.3849
# Epoch 457 - Train Loss: 1.3830 - Val Loss: 1.3848
# Epoch 458 - Train Loss: 1.3829 - Val Loss: 1.3848
# Epoch 459 - Train Loss: 1.3829 - Val Loss: 1.3848
# Epoch 460 - Train Loss: 1.3829 - Val Loss: 1.3847
# Epoch 461 - Train Loss: 1.3828 - Val Loss: 1.3847
# Epoch 462 - Train Loss: 1.3828 - Val Loss: 1.3846
# Epoch 463 - Train Loss: 1.3827 - Val Loss: 1.3846
# Epoch 464 - Train Loss: 1.3827 - Val Loss: 1.3846
# Epoch 465 - Train Loss: 1.3827 - Val Loss: 1.3845
# Epoch 466 - Train Loss: 1.3826 - Val Loss: 1.3845
# Epoch 467 - Train Loss: 1.3826 - Val Loss: 1.3845
# Epoch 468 - Train Loss: 1.3826 - Val Loss: 1.3844
# Epoch 469 - Train Loss: 1.3825 - Val Loss: 1.3844
# Epoch 470 - Train Loss: 1.3825 - Val Loss: 1.3844
# Epoch 471 - Train Loss: 1.3824 - Val Loss: 1.3843
# Epoch 472 - Train Loss: 1.3824 - Val Loss: 1.3843
# Epoch 473 - Train Loss: 1.3824 - Val Loss: 1.3843
# Epoch 474 - Train Loss: 1.3823 - Val Loss: 1.3843
# Epoch 475 - Train Loss: 1.3823 - Val Loss: 1.3842
# Epoch 476 - Train Loss: 1.3823 - Val Loss: 1.3842
# Epoch 477 - Train Loss: 1.3822 - Val Loss: 1.3842
# Epoch 478 - Train Loss: 1.3822 - Val Loss: 1.3841
# Epoch 479 - Train Loss: 1.3822 - Val Loss: 1.3841
# Epoch 480 - Train Loss: 1.3821 - Val Loss: 1.3841
# Epoch 481 - Train Loss: 1.3821 - Val Loss: 1.3840
# Epoch 482 - Train Loss: 1.3821 - Val Loss: 1.3840
# Epoch 483 - Train Loss: 1.3820 - Val Loss: 1.3840
# Epoch 484 - Train Loss: 1.3820 - Val Loss: 1.3839
# Epoch 485 - Train Loss: 1.3819 - Val Loss: 1.3839
# Epoch 486 - Train Loss: 1.3819 - Val Loss: 1.3839
# Epoch 487 - Train Loss: 1.3819 - Val Loss: 1.3838
# Epoch 488 - Train Loss: 1.3818 - Val Loss: 1.3838
# Epoch 489 - Train Loss: 1.3818 - Val Loss: 1.3838
# Epoch 490 - Train Loss: 1.3818 - Val Loss: 1.3837
# Epoch 491 - Train Loss: 1.3817 - Val Loss: 1.3837
# Epoch 492 - Train Loss: 1.3817 - Val Loss: 1.3837
# Epoch 493 - Train Loss: 1.3817 - Val Loss: 1.3837
# Epoch 494 - Train Loss: 1.3816 - Val Loss: 1.3836
# Epoch 495 - Train Loss: 1.3816 - Val Loss: 1.3836
# Epoch 496 - Train Loss: 1.3816 - Val Loss: 1.3836
# Epoch 497 - Train Loss: 1.3815 - Val Loss: 1.3835
# Epoch 498 - Train Loss: 1.3815 - Val Loss: 1.3835
# Epoch 499 - Train Loss: 1.3815 - Val Loss: 1.3835
# Epoch 500 - Train Loss: 1.3814 - Val Loss: 1.3835
# Epoch 501 - Train Loss: 1.3814 - Val Loss: 1.3834
# Epoch 502 - Train Loss: 1.3814 - Val Loss: 1.3834
# Epoch 503 - Train Loss: 1.3813 - Val Loss: 1.3834
# Epoch 504 - Train Loss: 1.3813 - Val Loss: 1.3833
# Epoch 505 - Train Loss: 1.3813 - Val Loss: 1.3833
# Epoch 506 - Train Loss: 1.3812 - Val Loss: 1.3833
# Epoch 507 - Train Loss: 1.3812 - Val Loss: 1.3833
# Epoch 508 - Train Loss: 1.3812 - Val Loss: 1.3832
# Epoch 509 - Train Loss: 1.3811 - Val Loss: 1.3832
# Epoch 510 - Train Loss: 1.3811 - Val Loss: 1.3832
# Epoch 511 - Train Loss: 1.3811 - Val Loss: 1.3831
# Epoch 512 - Train Loss: 1.3811 - Val Loss: 1.3831
# Epoch 513 - Train Loss: 1.3810 - Val Loss: 1.3831
# Epoch 514 - Train Loss: 1.3810 - Val Loss: 1.3831
# Epoch 515 - Train Loss: 1.3810 - Val Loss: 1.3830
# Epoch 516 - Train Loss: 1.3809 - Val Loss: 1.3830
# Epoch 517 - Train Loss: 1.3809 - Val Loss: 1.3830
# Epoch 518 - Train Loss: 1.3809 - Val Loss: 1.3829
# Epoch 519 - Train Loss: 1.3808 - Val Loss: 1.3829
# Epoch 520 - Train Loss: 1.3808 - Val Loss: 1.3829
# Epoch 521 - Train Loss: 1.3808 - Val Loss: 1.3829
# Epoch 522 - Train Loss: 1.3807 - Val Loss: 1.3828
# Epoch 523 - Train Loss: 1.3807 - Val Loss: 1.3828
# Epoch 524 - Train Loss: 1.3807 - Val Loss: 1.3828
# Epoch 525 - Train Loss: 1.3807 - Val Loss: 1.3828
# Epoch 526 - Train Loss: 1.3806 - Val Loss: 1.3827
# Epoch 527 - Train Loss: 1.3806 - Val Loss: 1.3827
# Epoch 528 - Train Loss: 1.3806 - Val Loss: 1.3827
# Epoch 529 - Train Loss: 1.3805 - Val Loss: 1.3827
# Epoch 530 - Train Loss: 1.3805 - Val Loss: 1.3826
# Epoch 531 - Train Loss: 1.3805 - Val Loss: 1.3826
# Epoch 532 - Train Loss: 1.3804 - Val Loss: 1.3826
# Epoch 533 - Train Loss: 1.3804 - Val Loss: 1.3825
# Epoch 534 - Train Loss: 1.3804 - Val Loss: 1.3825
# Epoch 535 - Train Loss: 1.3804 - Val Loss: 1.3825
# Epoch 536 - Train Loss: 1.3803 - Val Loss: 1.3825
# Epoch 537 - Train Loss: 1.3803 - Val Loss: 1.3824
# Epoch 538 - Train Loss: 1.3803 - Val Loss: 1.3824
# Epoch 539 - Train Loss: 1.3802 - Val Loss: 1.3824
# Epoch 540 - Train Loss: 1.3802 - Val Loss: 1.3824
# Epoch 541 - Train Loss: 1.3802 - Val Loss: 1.3823
# Epoch 542 - Train Loss: 1.3802 - Val Loss: 1.3823
# Epoch 543 - Train Loss: 1.3801 - Val Loss: 1.3823
# Epoch 544 - Train Loss: 1.3801 - Val Loss: 1.3823
# Epoch 545 - Train Loss: 1.3801 - Val Loss: 1.3822
# Epoch 546 - Train Loss: 1.3801 - Val Loss: 1.3822
# Epoch 547 - Train Loss: 1.3800 - Val Loss: 1.3822
# Epoch 548 - Train Loss: 1.3800 - Val Loss: 1.3822
# Epoch 549 - Train Loss: 1.3800 - Val Loss: 1.3822
# Epoch 550 - Train Loss: 1.3799 - Val Loss: 1.3821
# Epoch 551 - Train Loss: 1.3799 - Val Loss: 1.3821
# Epoch 552 - Train Loss: 1.3799 - Val Loss: 1.3821
# Epoch 553 - Train Loss: 1.3799 - Val Loss: 1.3821
# Epoch 554 - Train Loss: 1.3798 - Val Loss: 1.3820
# Epoch 555 - Train Loss: 1.3798 - Val Loss: 1.3820
# Epoch 556 - Train Loss: 1.3798 - Val Loss: 1.3820
# Epoch 557 - Train Loss: 1.3798 - Val Loss: 1.3820
# Epoch 558 - Train Loss: 1.3797 - Val Loss: 1.3819
# Epoch 559 - Train Loss: 1.3797 - Val Loss: 1.3819
# Epoch 560 - Train Loss: 1.3797 - Val Loss: 1.3819
# Epoch 561 - Train Loss: 1.3796 - Val Loss: 1.3819
# Epoch 562 - Train Loss: 1.3796 - Val Loss: 1.3818
# Epoch 563 - Train Loss: 1.3796 - Val Loss: 1.3818
# Epoch 564 - Train Loss: 1.3796 - Val Loss: 1.3818
# Epoch 565 - Train Loss: 1.3795 - Val Loss: 1.3818
# Epoch 566 - Train Loss: 1.3795 - Val Loss: 1.3818
# Epoch 567 - Train Loss: 1.3795 - Val Loss: 1.3817
# Epoch 568 - Train Loss: 1.3795 - Val Loss: 1.3817
# Epoch 569 - Train Loss: 1.3794 - Val Loss: 1.3817
# Epoch 570 - Train Loss: 1.3794 - Val Loss: 1.3817
# Epoch 571 - Train Loss: 1.3794 - Val Loss: 1.3816
# Epoch 572 - Train Loss: 1.3794 - Val Loss: 1.3816
# Epoch 573 - Train Loss: 1.3793 - Val Loss: 1.3816
# Epoch 574 - Train Loss: 1.3793 - Val Loss: 1.3816
# Epoch 575 - Train Loss: 1.3793 - Val Loss: 1.3815
# Epoch 576 - Train Loss: 1.3793 - Val Loss: 1.3815
# Epoch 577 - Train Loss: 1.3792 - Val Loss: 1.3815
# Epoch 578 - Train Loss: 1.3792 - Val Loss: 1.3815
# Epoch 579 - Train Loss: 1.3792 - Val Loss: 1.3815
# Epoch 580 - Train Loss: 1.3792 - Val Loss: 1.3814
# Epoch 581 - Train Loss: 1.3791 - Val Loss: 1.3814
# Epoch 582 - Train Loss: 1.3791 - Val Loss: 1.3814
# Epoch 583 - Train Loss: 1.3791 - Val Loss: 1.3814
# Epoch 584 - Train Loss: 1.3791 - Val Loss: 1.3813
# Epoch 585 - Train Loss: 1.3790 - Val Loss: 1.3813
# Epoch 586 - Train Loss: 1.3790 - Val Loss: 1.3813
# Epoch 587 - Train Loss: 1.3790 - Val Loss: 1.3813
# Epoch 588 - Train Loss: 1.3790 - Val Loss: 1.3813
# Epoch 589 - Train Loss: 1.3789 - Val Loss: 1.3812
# Epoch 590 - Train Loss: 1.3789 - Val Loss: 1.3812
# Epoch 591 - Train Loss: 1.3789 - Val Loss: 1.3812
# Epoch 592 - Train Loss: 1.3789 - Val Loss: 1.3812
# Epoch 593 - Train Loss: 1.3788 - Val Loss: 1.3812
# Epoch 594 - Train Loss: 1.3788 - Val Loss: 1.3811
# Epoch 595 - Train Loss: 1.3788 - Val Loss: 1.3811
# Epoch 596 - Train Loss: 1.3788 - Val Loss: 1.3811
# Epoch 597 - Train Loss: 1.3787 - Val Loss: 1.3811
# Epoch 598 - Train Loss: 1.3787 - Val Loss: 1.3811
# Epoch 599 - Train Loss: 1.3787 - Val Loss: 1.3810
# Epoch 600 - Train Loss: 1.3787 - Val Loss: 1.3810
# Epoch 601 - Train Loss: 1.3787 - Val Loss: 1.3810
# Epoch 602 - Train Loss: 1.3786 - Val Loss: 1.3810
# Epoch 603 - Train Loss: 1.3786 - Val Loss: 1.3809
# Epoch 604 - Train Loss: 1.3786 - Val Loss: 1.3809
# Epoch 605 - Train Loss: 1.3786 - Val Loss: 1.3809
# Epoch 606 - Train Loss: 1.3785 - Val Loss: 1.3809
# Epoch 607 - Train Loss: 1.3785 - Val Loss: 1.3809
# Epoch 608 - Train Loss: 1.3785 - Val Loss: 1.3808
# Epoch 609 - Train Loss: 1.3785 - Val Loss: 1.3808
# Epoch 610 - Train Loss: 1.3784 - Val Loss: 1.3808
# Epoch 611 - Train Loss: 1.3784 - Val Loss: 1.3808
# Epoch 612 - Train Loss: 1.3784 - Val Loss: 1.3808
# Epoch 613 - Train Loss: 1.3784 - Val Loss: 1.3807
# Epoch 614 - Train Loss: 1.3784 - Val Loss: 1.3807
# Epoch 615 - Train Loss: 1.3783 - Val Loss: 1.3807
# Epoch 616 - Train Loss: 1.3783 - Val Loss: 1.3807
# Epoch 617 - Train Loss: 1.3783 - Val Loss: 1.3807
# Epoch 618 - Train Loss: 1.3783 - Val Loss: 1.3806
# Epoch 619 - Train Loss: 1.3782 - Val Loss: 1.3806
# Epoch 620 - Train Loss: 1.3782 - Val Loss: 1.3806
# Epoch 621 - Train Loss: 1.3782 - Val Loss: 1.3806
# Epoch 622 - Train Loss: 1.3782 - Val Loss: 1.3806
# Epoch 623 - Train Loss: 1.3782 - Val Loss: 1.3805
# Epoch 624 - Train Loss: 1.3781 - Val Loss: 1.3805
# Epoch 625 - Train Loss: 1.3781 - Val Loss: 1.3805
# Epoch 626 - Train Loss: 1.3781 - Val Loss: 1.3805
# Epoch 627 - Train Loss: 1.3781 - Val Loss: 1.3805
# Epoch 628 - Train Loss: 1.3780 - Val Loss: 1.3805
# Epoch 629 - Train Loss: 1.3780 - Val Loss: 1.3804
# Epoch 630 - Train Loss: 1.3780 - Val Loss: 1.3804
# Epoch 631 - Train Loss: 1.3780 - Val Loss: 1.3804
# Epoch 632 - Train Loss: 1.3780 - Val Loss: 1.3804
# Epoch 633 - Train Loss: 1.3779 - Val Loss: 1.3804
# Epoch 634 - Train Loss: 1.3779 - Val Loss: 1.3803
# Epoch 635 - Train Loss: 1.3779 - Val Loss: 1.3803
# Epoch 636 - Train Loss: 1.3779 - Val Loss: 1.3803
# Epoch 637 - Train Loss: 1.3778 - Val Loss: 1.3803
# Epoch 638 - Train Loss: 1.3778 - Val Loss: 1.3803
# Epoch 639 - Train Loss: 1.3778 - Val Loss: 1.3802
# Epoch 640 - Train Loss: 1.3778 - Val Loss: 1.3802
# Epoch 641 - Train Loss: 1.3778 - Val Loss: 1.3802
# Epoch 642 - Train Loss: 1.3777 - Val Loss: 1.3802
# Epoch 643 - Train Loss: 1.3777 - Val Loss: 1.3802
# Epoch 644 - Train Loss: 1.3777 - Val Loss: 1.3802
# Epoch 645 - Train Loss: 1.3777 - Val Loss: 1.3801
# Epoch 646 - Train Loss: 1.3777 - Val Loss: 1.3801
# Epoch 647 - Train Loss: 1.3776 - Val Loss: 1.3801
# Epoch 648 - Train Loss: 1.3776 - Val Loss: 1.3801
# Epoch 649 - Train Loss: 1.3776 - Val Loss: 1.3801
# Epoch 650 - Train Loss: 1.3776 - Val Loss: 1.3800
# Epoch 651 - Train Loss: 1.3776 - Val Loss: 1.3800
# Epoch 652 - Train Loss: 1.3775 - Val Loss: 1.3800
# Epoch 653 - Train Loss: 1.3775 - Val Loss: 1.3800
# Epoch 654 - Train Loss: 1.3775 - Val Loss: 1.3800
# Epoch 655 - Train Loss: 1.3775 - Val Loss: 1.3799
# Epoch 656 - Train Loss: 1.3775 - Val Loss: 1.3799
# Epoch 657 - Train Loss: 1.3774 - Val Loss: 1.3799
# Epoch 658 - Train Loss: 1.3774 - Val Loss: 1.3799
# Epoch 659 - Train Loss: 1.3774 - Val Loss: 1.3799
# Epoch 660 - Train Loss: 1.3774 - Val Loss: 1.3799
# Epoch 661 - Train Loss: 1.3774 - Val Loss: 1.3798
# Epoch 662 - Train Loss: 1.3773 - Val Loss: 1.3798
# Epoch 663 - Train Loss: 1.3773 - Val Loss: 1.3798
# Epoch 664 - Train Loss: 1.3773 - Val Loss: 1.3798
# Epoch 665 - Train Loss: 1.3773 - Val Loss: 1.3798
# Epoch 666 - Train Loss: 1.3772 - Val Loss: 1.3798
# Epoch 667 - Train Loss: 1.3772 - Val Loss: 1.3797
# Epoch 668 - Train Loss: 1.3772 - Val Loss: 1.3797
# Epoch 669 - Train Loss: 1.3772 - Val Loss: 1.3797
# Epoch 670 - Train Loss: 1.3772 - Val Loss: 1.3797
# Epoch 671 - Train Loss: 1.3772 - Val Loss: 1.3797
# Epoch 672 - Train Loss: 1.3771 - Val Loss: 1.3796
# Epoch 673 - Train Loss: 1.3771 - Val Loss: 1.3796
# Epoch 674 - Train Loss: 1.3771 - Val Loss: 1.3796
# Epoch 675 - Train Loss: 1.3771 - Val Loss: 1.3796
# Epoch 676 - Train Loss: 1.3771 - Val Loss: 1.3796
# Epoch 677 - Train Loss: 1.3770 - Val Loss: 1.3796
# Epoch 678 - Train Loss: 1.3770 - Val Loss: 1.3795
# Epoch 679 - Train Loss: 1.3770 - Val Loss: 1.3795
# Epoch 680 - Train Loss: 1.3770 - Val Loss: 1.3795
# Epoch 681 - Train Loss: 1.3770 - Val Loss: 1.3795
# Epoch 682 - Train Loss: 1.3769 - Val Loss: 1.3795
# Epoch 683 - Train Loss: 1.3769 - Val Loss: 1.3795
# Epoch 684 - Train Loss: 1.3769 - Val Loss: 1.3794
# Epoch 685 - Train Loss: 1.3769 - Val Loss: 1.3794
# Epoch 686 - Train Loss: 1.3769 - Val Loss: 1.3794
# Epoch 687 - Train Loss: 1.3768 - Val Loss: 1.3794
# Epoch 688 - Train Loss: 1.3768 - Val Loss: 1.3794
# Epoch 689 - Train Loss: 1.3768 - Val Loss: 1.3794
# Epoch 690 - Train Loss: 1.3768 - Val Loss: 1.3793
# Epoch 691 - Train Loss: 1.3768 - Val Loss: 1.3793
# Epoch 692 - Train Loss: 1.3767 - Val Loss: 1.3793
# Epoch 693 - Train Loss: 1.3767 - Val Loss: 1.3793
# Epoch 694 - Train Loss: 1.3767 - Val Loss: 1.3793
# Epoch 695 - Train Loss: 1.3767 - Val Loss: 1.3793
# Epoch 696 - Train Loss: 1.3767 - Val Loss: 1.3792
# Epoch 697 - Train Loss: 1.3767 - Val Loss: 1.3792
# Epoch 698 - Train Loss: 1.3766 - Val Loss: 1.3792
# Epoch 699 - Train Loss: 1.3766 - Val Loss: 1.3792
# Epoch 700 - Train Loss: 1.3766 - Val Loss: 1.3792
# Epoch 701 - Train Loss: 1.3766 - Val Loss: 1.3792
# Epoch 702 - Train Loss: 1.3766 - Val Loss: 1.3791
# Epoch 703 - Train Loss: 1.3765 - Val Loss: 1.3791
# Epoch 704 - Train Loss: 1.3765 - Val Loss: 1.3791
# Epoch 705 - Train Loss: 1.3765 - Val Loss: 1.3791
# Epoch 706 - Train Loss: 1.3765 - Val Loss: 1.3791
# Epoch 707 - Train Loss: 1.3765 - Val Loss: 1.3791
# Epoch 708 - Train Loss: 1.3764 - Val Loss: 1.3790
# Epoch 709 - Train Loss: 1.3764 - Val Loss: 1.3790
# Epoch 710 - Train Loss: 1.3764 - Val Loss: 1.3790
# Epoch 711 - Train Loss: 1.3764 - Val Loss: 1.3790
# Epoch 712 - Train Loss: 1.3764 - Val Loss: 1.3790
# Epoch 713 - Train Loss: 1.3764 - Val Loss: 1.3790
# Epoch 714 - Train Loss: 1.3763 - Val Loss: 1.3789
# Epoch 715 - Train Loss: 1.3763 - Val Loss: 1.3789
# Epoch 716 - Train Loss: 1.3763 - Val Loss: 1.3789
# Epoch 717 - Train Loss: 1.3763 - Val Loss: 1.3789
# Epoch 718 - Train Loss: 1.3763 - Val Loss: 1.3789
# Epoch 719 - Train Loss: 1.3762 - Val Loss: 1.3789
# Epoch 720 - Train Loss: 1.3762 - Val Loss: 1.3789
# Epoch 721 - Train Loss: 1.3762 - Val Loss: 1.3788
# Epoch 722 - Train Loss: 1.3762 - Val Loss: 1.3788
# Epoch 723 - Train Loss: 1.3762 - Val Loss: 1.3788
# Epoch 724 - Train Loss: 1.3762 - Val Loss: 1.3788
# Epoch 725 - Train Loss: 1.3761 - Val Loss: 1.3788
# Epoch 726 - Train Loss: 1.3761 - Val Loss: 1.3788
# Epoch 727 - Train Loss: 1.3761 - Val Loss: 1.3787
# Epoch 728 - Train Loss: 1.3761 - Val Loss: 1.3787
# Epoch 729 - Train Loss: 1.3761 - Val Loss: 1.3787
# Epoch 730 - Train Loss: 1.3761 - Val Loss: 1.3787
# Epoch 731 - Train Loss: 1.3760 - Val Loss: 1.3787
# Epoch 732 - Train Loss: 1.3760 - Val Loss: 1.3787
# Epoch 733 - Train Loss: 1.3760 - Val Loss: 1.3786
# Epoch 734 - Train Loss: 1.3760 - Val Loss: 1.3786
# Epoch 735 - Train Loss: 1.3760 - Val Loss: 1.3786
# Epoch 736 - Train Loss: 1.3759 - Val Loss: 1.3786
# Epoch 737 - Train Loss: 1.3759 - Val Loss: 1.3786
# Epoch 738 - Train Loss: 1.3759 - Val Loss: 1.3786
# Epoch 739 - Train Loss: 1.3759 - Val Loss: 1.3786
# Epoch 740 - Train Loss: 1.3759 - Val Loss: 1.3785
# Epoch 741 - Train Loss: 1.3759 - Val Loss: 1.3785
# Epoch 742 - Train Loss: 1.3758 - Val Loss: 1.3785
# Epoch 743 - Train Loss: 1.3758 - Val Loss: 1.3785
# Epoch 744 - Train Loss: 1.3758 - Val Loss: 1.3785
# Epoch 745 - Train Loss: 1.3758 - Val Loss: 1.3785
# Epoch 746 - Train Loss: 1.3758 - Val Loss: 1.3784
# Epoch 747 - Train Loss: 1.3758 - Val Loss: 1.3784
# Epoch 748 - Train Loss: 1.3757 - Val Loss: 1.3784
# Epoch 749 - Train Loss: 1.3757 - Val Loss: 1.3784
# Epoch 750 - Train Loss: 1.3757 - Val Loss: 1.3784
# Epoch 751 - Train Loss: 1.3757 - Val Loss: 1.3784
# Epoch 752 - Train Loss: 1.3757 - Val Loss: 1.3784
# Epoch 753 - Train Loss: 1.3757 - Val Loss: 1.3783
# Epoch 754 - Train Loss: 1.3756 - Val Loss: 1.3783
# Epoch 755 - Train Loss: 1.3756 - Val Loss: 1.3783
# Epoch 756 - Train Loss: 1.3756 - Val Loss: 1.3783
# Epoch 757 - Train Loss: 1.3756 - Val Loss: 1.3783
# Epoch 758 - Train Loss: 1.3756 - Val Loss: 1.3783
# Epoch 759 - Train Loss: 1.3756 - Val Loss: 1.3783
# Epoch 760 - Train Loss: 1.3755 - Val Loss: 1.3782
# Epoch 761 - Train Loss: 1.3755 - Val Loss: 1.3782
# Epoch 762 - Train Loss: 1.3755 - Val Loss: 1.3782
# Epoch 763 - Train Loss: 1.3755 - Val Loss: 1.3782
# Epoch 764 - Train Loss: 1.3755 - Val Loss: 1.3782
# Epoch 765 - Train Loss: 1.3755 - Val Loss: 1.3782
# Epoch 766 - Train Loss: 1.3754 - Val Loss: 1.3782
# Epoch 767 - Train Loss: 1.3754 - Val Loss: 1.3781
# Epoch 768 - Train Loss: 1.3754 - Val Loss: 1.3781
# Epoch 769 - Train Loss: 1.3754 - Val Loss: 1.3781
# Epoch 770 - Train Loss: 1.3754 - Val Loss: 1.3781
# Epoch 771 - Train Loss: 1.3754 - Val Loss: 1.3781
# Epoch 772 - Train Loss: 1.3753 - Val Loss: 1.3781
# Epoch 773 - Train Loss: 1.3753 - Val Loss: 1.3780
# Epoch 774 - Train Loss: 1.3753 - Val Loss: 1.3780
# Epoch 775 - Train Loss: 1.3753 - Val Loss: 1.3780
# Epoch 776 - Train Loss: 1.3753 - Val Loss: 1.3780
# Epoch 777 - Train Loss: 1.3753 - Val Loss: 1.3780
# Epoch 778 - Train Loss: 1.3752 - Val Loss: 1.3780
# Epoch 779 - Train Loss: 1.3752 - Val Loss: 1.3780
# Epoch 780 - Train Loss: 1.3752 - Val Loss: 1.3779
# Epoch 781 - Train Loss: 1.3752 - Val Loss: 1.3779
# Epoch 782 - Train Loss: 1.3752 - Val Loss: 1.3779
# Epoch 783 - Train Loss: 1.3752 - Val Loss: 1.3779
# Epoch 784 - Train Loss: 1.3752 - Val Loss: 1.3779
# Epoch 785 - Train Loss: 1.3751 - Val Loss: 1.3779
# Epoch 786 - Train Loss: 1.3751 - Val Loss: 1.3779
# Epoch 787 - Train Loss: 1.3751 - Val Loss: 1.3778
# Epoch 788 - Train Loss: 1.3751 - Val Loss: 1.3778
# Epoch 789 - Train Loss: 1.3751 - Val Loss: 1.3778
# Epoch 790 - Train Loss: 1.3751 - Val Loss: 1.3778
# Epoch 791 - Train Loss: 1.3750 - Val Loss: 1.3778
# Epoch 792 - Train Loss: 1.3750 - Val Loss: 1.3778
# Epoch 793 - Train Loss: 1.3750 - Val Loss: 1.3778
# Epoch 794 - Train Loss: 1.3750 - Val Loss: 1.3778
# Epoch 795 - Train Loss: 1.3750 - Val Loss: 1.3777
# Epoch 796 - Train Loss: 1.3750 - Val Loss: 1.3777
# Epoch 797 - Train Loss: 1.3749 - Val Loss: 1.3777
# Epoch 798 - Train Loss: 1.3749 - Val Loss: 1.3777
# Epoch 799 - Train Loss: 1.3749 - Val Loss: 1.3777
# Epoch 800 - Train Loss: 1.3749 - Val Loss: 1.3777
# Epoch 801 - Train Loss: 1.3749 - Val Loss: 1.3777
# Epoch 802 - Train Loss: 1.3749 - Val Loss: 1.3776
# Epoch 803 - Train Loss: 1.3749 - Val Loss: 1.3776
# Epoch 804 - Train Loss: 1.3748 - Val Loss: 1.3776
# Epoch 805 - Train Loss: 1.3748 - Val Loss: 1.3776
# Epoch 806 - Train Loss: 1.3748 - Val Loss: 1.3776
# Epoch 807 - Train Loss: 1.3748 - Val Loss: 1.3776
# Epoch 808 - Train Loss: 1.3748 - Val Loss: 1.3776
# Epoch 809 - Train Loss: 1.3748 - Val Loss: 1.3775
# Epoch 810 - Train Loss: 1.3748 - Val Loss: 1.3775
# Epoch 811 - Train Loss: 1.3747 - Val Loss: 1.3775
# Epoch 812 - Train Loss: 1.3747 - Val Loss: 1.3775
# Epoch 813 - Train Loss: 1.3747 - Val Loss: 1.3775
# Epoch 814 - Train Loss: 1.3747 - Val Loss: 1.3775
# Epoch 815 - Train Loss: 1.3747 - Val Loss: 1.3775
# Epoch 816 - Train Loss: 1.3747 - Val Loss: 1.3775
# Epoch 817 - Train Loss: 1.3746 - Val Loss: 1.3774
# Epoch 818 - Train Loss: 1.3746 - Val Loss: 1.3774
# Epoch 819 - Train Loss: 1.3746 - Val Loss: 1.3774
# Epoch 820 - Train Loss: 1.3746 - Val Loss: 1.3774
# Epoch 821 - Train Loss: 1.3746 - Val Loss: 1.3774
# Epoch 822 - Train Loss: 1.3746 - Val Loss: 1.3774
# Epoch 823 - Train Loss: 1.3746 - Val Loss: 1.3774
# Epoch 824 - Train Loss: 1.3745 - Val Loss: 1.3773
# Epoch 825 - Train Loss: 1.3745 - Val Loss: 1.3773
# Epoch 826 - Train Loss: 1.3745 - Val Loss: 1.3773
# Epoch 827 - Train Loss: 1.3745 - Val Loss: 1.3773
# Epoch 828 - Train Loss: 1.3745 - Val Loss: 1.3773
# Epoch 829 - Train Loss: 1.3745 - Val Loss: 1.3773
# Epoch 830 - Train Loss: 1.3745 - Val Loss: 1.3773
# Epoch 831 - Train Loss: 1.3744 - Val Loss: 1.3773
# Epoch 832 - Train Loss: 1.3744 - Val Loss: 1.3772
# Epoch 833 - Train Loss: 1.3744 - Val Loss: 1.3772
# Epoch 834 - Train Loss: 1.3744 - Val Loss: 1.3772
# Epoch 835 - Train Loss: 1.3744 - Val Loss: 1.3772
# Epoch 836 - Train Loss: 1.3744 - Val Loss: 1.3772
# Epoch 837 - Train Loss: 1.3744 - Val Loss: 1.3772
# Epoch 838 - Train Loss: 1.3743 - Val Loss: 1.3772
# Epoch 839 - Train Loss: 1.3743 - Val Loss: 1.3771
# Epoch 840 - Train Loss: 1.3743 - Val Loss: 1.3771
# Epoch 841 - Train Loss: 1.3743 - Val Loss: 1.3771
# Epoch 842 - Train Loss: 1.3743 - Val Loss: 1.3771
# Epoch 843 - Train Loss: 1.3743 - Val Loss: 1.3771
# Epoch 844 - Train Loss: 1.3743 - Val Loss: 1.3771
# Epoch 845 - Train Loss: 1.3742 - Val Loss: 1.3771
# Epoch 846 - Train Loss: 1.3742 - Val Loss: 1.3771
# Epoch 847 - Train Loss: 1.3742 - Val Loss: 1.3770
# Epoch 848 - Train Loss: 1.3742 - Val Loss: 1.3770
# Epoch 849 - Train Loss: 1.3742 - Val Loss: 1.3770
# Epoch 850 - Train Loss: 1.3742 - Val Loss: 1.3770
# Epoch 851 - Train Loss: 1.3742 - Val Loss: 1.3770
# Epoch 852 - Train Loss: 1.3741 - Val Loss: 1.3770
# Epoch 853 - Train Loss: 1.3741 - Val Loss: 1.3770
# Epoch 854 - Train Loss: 1.3741 - Val Loss: 1.3770
# Epoch 855 - Train Loss: 1.3741 - Val Loss: 1.3769
# Epoch 856 - Train Loss: 1.3741 - Val Loss: 1.3769
# Epoch 857 - Train Loss: 1.3741 - Val Loss: 1.3769
# Epoch 858 - Train Loss: 1.3741 - Val Loss: 1.3769
# Epoch 859 - Train Loss: 1.3740 - Val Loss: 1.3769
# Epoch 860 - Train Loss: 1.3740 - Val Loss: 1.3769
# Epoch 861 - Train Loss: 1.3740 - Val Loss: 1.3769
# Epoch 862 - Train Loss: 1.3740 - Val Loss: 1.3769
# Epoch 863 - Train Loss: 1.3740 - Val Loss: 1.3768
# Epoch 864 - Train Loss: 1.3740 - Val Loss: 1.3768
# Epoch 865 - Train Loss: 1.3740 - Val Loss: 1.3768
# Epoch 866 - Train Loss: 1.3739 - Val Loss: 1.3768
# Epoch 867 - Train Loss: 1.3739 - Val Loss: 1.3768
# Epoch 868 - Train Loss: 1.3739 - Val Loss: 1.3768
# Epoch 869 - Train Loss: 1.3739 - Val Loss: 1.3768
# Epoch 870 - Train Loss: 1.3739 - Val Loss: 1.3768
# Epoch 871 - Train Loss: 1.3739 - Val Loss: 1.3767
# Epoch 872 - Train Loss: 1.3739 - Val Loss: 1.3767
# Epoch 873 - Train Loss: 1.3738 - Val Loss: 1.3767
# Epoch 874 - Train Loss: 1.3738 - Val Loss: 1.3767
# Epoch 875 - Train Loss: 1.3738 - Val Loss: 1.3767
# Epoch 876 - Train Loss: 1.3738 - Val Loss: 1.3767
# Epoch 877 - Train Loss: 1.3738 - Val Loss: 1.3767
# Epoch 878 - Train Loss: 1.3738 - Val Loss: 1.3767
# Epoch 879 - Train Loss: 1.3738 - Val Loss: 1.3767
# Epoch 880 - Train Loss: 1.3738 - Val Loss: 1.3766
# Epoch 881 - Train Loss: 1.3737 - Val Loss: 1.3766
# Epoch 882 - Train Loss: 1.3737 - Val Loss: 1.3766
# Epoch 883 - Train Loss: 1.3737 - Val Loss: 1.3766
# Epoch 884 - Train Loss: 1.3737 - Val Loss: 1.3766
# Epoch 885 - Train Loss: 1.3737 - Val Loss: 1.3766
# Epoch 886 - Train Loss: 1.3737 - Val Loss: 1.3766
# Epoch 887 - Train Loss: 1.3737 - Val Loss: 1.3766
# Epoch 888 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 889 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 890 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 891 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 892 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 893 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 894 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 895 - Train Loss: 1.3736 - Val Loss: 1.3765
# Epoch 896 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 897 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 898 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 899 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 900 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 901 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 902 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 903 - Train Loss: 1.3735 - Val Loss: 1.3764
# Epoch 904 - Train Loss: 1.3734 - Val Loss: 1.3764
# Epoch 905 - Train Loss: 1.3734 - Val Loss: 1.3763
# Epoch 906 - Train Loss: 1.3734 - Val Loss: 1.3763
# Epoch 907 - Train Loss: 1.3734 - Val Loss: 1.3763
# Epoch 908 - Train Loss: 1.3734 - Val Loss: 1.3763
# Epoch 909 - Train Loss: 1.3734 - Val Loss: 1.3763
# Epoch 910 - Train Loss: 1.3734 - Val Loss: 1.3763
# Epoch 911 - Train Loss: 1.3734 - Val Loss: 1.3763
# Epoch 912 - Train Loss: 1.3733 - Val Loss: 1.3763
# Epoch 913 - Train Loss: 1.3733 - Val Loss: 1.3763
# Epoch 914 - Train Loss: 1.3733 - Val Loss: 1.3762
# Epoch 915 - Train Loss: 1.3733 - Val Loss: 1.3762
# Epoch 916 - Train Loss: 1.3733 - Val Loss: 1.3762
# Epoch 917 - Train Loss: 1.3733 - Val Loss: 1.3762
# Epoch 918 - Train Loss: 1.3733 - Val Loss: 1.3762
# Epoch 919 - Train Loss: 1.3733 - Val Loss: 1.3762
# Epoch 920 - Train Loss: 1.3732 - Val Loss: 1.3762
# Epoch 921 - Train Loss: 1.3732 - Val Loss: 1.3762
# Epoch 922 - Train Loss: 1.3732 - Val Loss: 1.3762
# Epoch 923 - Train Loss: 1.3732 - Val Loss: 1.3761
# Epoch 924 - Train Loss: 1.3732 - Val Loss: 1.3761
# Epoch 925 - Train Loss: 1.3732 - Val Loss: 1.3761
# Epoch 926 - Train Loss: 1.3732 - Val Loss: 1.3761
# Epoch 927 - Train Loss: 1.3732 - Val Loss: 1.3761
# Epoch 928 - Train Loss: 1.3731 - Val Loss: 1.3761
# Epoch 929 - Train Loss: 1.3731 - Val Loss: 1.3761
# Epoch 930 - Train Loss: 1.3731 - Val Loss: 1.3761
# Epoch 931 - Train Loss: 1.3731 - Val Loss: 1.3761
# Epoch 932 - Train Loss: 1.3731 - Val Loss: 1.3760
# Epoch 933 - Train Loss: 1.3731 - Val Loss: 1.3760
# Epoch 934 - Train Loss: 1.3731 - Val Loss: 1.3760
# Epoch 935 - Train Loss: 1.3731 - Val Loss: 1.3760
# Epoch 936 - Train Loss: 1.3730 - Val Loss: 1.3760
# Epoch 937 - Train Loss: 1.3730 - Val Loss: 1.3760
# Epoch 938 - Train Loss: 1.3730 - Val Loss: 1.3760
# Epoch 939 - Train Loss: 1.3730 - Val Loss: 1.3760
# Epoch 940 - Train Loss: 1.3730 - Val Loss: 1.3760
# Epoch 941 - Train Loss: 1.3730 - Val Loss: 1.3759
# Epoch 942 - Train Loss: 1.3730 - Val Loss: 1.3759
# Epoch 943 - Train Loss: 1.3730 - Val Loss: 1.3759
# Epoch 944 - Train Loss: 1.3729 - Val Loss: 1.3759
# Epoch 945 - Train Loss: 1.3729 - Val Loss: 1.3759
# Epoch 946 - Train Loss: 1.3729 - Val Loss: 1.3759
# Epoch 947 - Train Loss: 1.3729 - Val Loss: 1.3759
# Epoch 948 - Train Loss: 1.3729 - Val Loss: 1.3759
# Epoch 949 - Train Loss: 1.3729 - Val Loss: 1.3759
# Epoch 950 - Train Loss: 1.3729 - Val Loss: 1.3758
# Epoch 951 - Train Loss: 1.3729 - Val Loss: 1.3758
# Epoch 952 - Train Loss: 1.3729 - Val Loss: 1.3758
# Epoch 953 - Train Loss: 1.3728 - Val Loss: 1.3758
# Epoch 954 - Train Loss: 1.3728 - Val Loss: 1.3758
# Epoch 955 - Train Loss: 1.3728 - Val Loss: 1.3758
# Epoch 956 - Train Loss: 1.3728 - Val Loss: 1.3758
# Epoch 957 - Train Loss: 1.3728 - Val Loss: 1.3758
# Epoch 958 - Train Loss: 1.3728 - Val Loss: 1.3758
# Epoch 959 - Train Loss: 1.3728 - Val Loss: 1.3758
# Epoch 960 - Train Loss: 1.3728 - Val Loss: 1.3757
# Epoch 961 - Train Loss: 1.3727 - Val Loss: 1.3757
# ...
# Epoch 1573 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1574 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1575 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1576 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1577 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1578 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1579 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1580 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1581 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1582 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1583 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1584 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1585 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1586 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1587 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1588 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1589 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1590 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1591 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1592 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1593 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1594 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1595 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1596 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1597 - Train Loss: 0.5969 - Val Loss: 0.5939
# Epoch 1598 - Train Loss: 0.5968 - Val Loss: 0.5939
# Epoch 1599 - Train Loss: 0.5968 - Val Loss: 0.5939
# Epoch 1600 - Train Loss: 0.5968 - Val Loss: 0.5939
# Epoch 1601 - Train Loss: 0.5968 - Val Loss: 0.5939
# Epoch 1602 - Train Loss: 0.5968 - Val Loss: 0.5939
# Epoch 1603 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1604 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1605 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1606 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1607 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1608 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1609 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1610 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1611 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1612 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1613 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1614 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1615 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1616 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1617 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1618 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1619 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1620 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1621 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1622 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1623 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1624 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1625 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1626 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1627 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1628 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1629 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1630 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1631 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1632 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1633 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1634 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1635 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1636 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1637 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1638 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1639 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1640 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1641 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1642 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1643 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1644 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1645 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1646 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1647 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1648 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1649 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1650 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1651 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1652 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1653 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1654 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1655 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1656 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1657 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1658 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1659 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1660 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1661 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1662 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1663 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1664 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1665 - Train Loss: 0.5968 - Val Loss: 0.5938
# Epoch 1666 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1667 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1668 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1669 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1670 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1671 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1672 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1673 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1674 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1675 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1676 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1677 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1678 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1679 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1680 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1681 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1682 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1683 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1684 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1685 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1686 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1687 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1688 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1689 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1690 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1691 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1692 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1693 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1694 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1695 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1696 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1697 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1698 - Train Loss: 0.5967 - Val Loss: 0.5938
# Epoch 1699 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1700 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1701 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1702 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1703 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1704 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1705 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1706 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1707 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1708 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1709 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1710 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1711 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1712 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1713 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1714 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1715 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1716 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1717 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1718 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1719 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1720 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1721 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1722 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1723 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1724 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1725 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1726 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1727 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1728 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1729 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1730 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1731 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1732 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1733 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1734 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1735 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1736 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1737 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1738 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1739 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1740 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1741 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1742 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1743 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1744 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1745 - Train Loss: 0.5967 - Val Loss: 0.5937
# Epoch 1746 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1747 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1748 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1749 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1750 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1751 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1752 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1753 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1754 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1755 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1756 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1757 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1758 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1759 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1760 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1761 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1762 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1763 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1764 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1765 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1766 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1767 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1768 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1769 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1770 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1771 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1772 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1773 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1774 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1775 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1776 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1777 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1778 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1779 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1780 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1781 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1782 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1783 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1784 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1785 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1786 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1787 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1788 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1789 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1790 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1791 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1792 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1793 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1794 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1795 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1796 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1797 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1798 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1799 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1800 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1801 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1802 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1803 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1804 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1805 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1806 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1807 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1808 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1809 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1810 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1811 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1812 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1813 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1814 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1815 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1816 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1817 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1818 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1819 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1820 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1821 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1822 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1823 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1824 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1825 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1826 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1827 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1828 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1829 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1830 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1831 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1832 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1833 - Train Loss: 0.5966 - Val Loss: 0.5937
# Epoch 1834 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1835 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1836 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1837 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1838 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1839 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1840 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1841 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1842 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1843 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1844 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1845 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1846 - Train Loss: 0.5966 - Val Loss: 0.5936
# Epoch 1847 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1848 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1849 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1850 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1851 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1852 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1853 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1854 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1855 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1856 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1857 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1858 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1859 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1860 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1861 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1862 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1863 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1864 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1865 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1866 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1867 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1868 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1869 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1870 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1871 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1872 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1873 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1874 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1875 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1876 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1877 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1878 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1879 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1880 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1881 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1882 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1883 - Train Loss: 0.5965 - Val Loss: 0.5936
# Epoch 1884 - Train Loss: 0.5965 - Val Loss: 0.5936
# Early stopping at epoch 1885. Best validation loss: 0.5936

# %%
import matplotlib.pyplot as plt

def plot_mean_effects(sim_list):

    fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = [20, 5])

    for element in sim_list:

        X_test = element["X_test"].numpy()
        F_test = element["F_test"]
        mu_components = element["mu_components"]
        robust_mu_components = element["robust_mu_components"]
        strict_mu_components = element["strict_mu_components"]

        # S_test = element["S_test"]
        # sigma_components = element["sigma_components"]
        # robust_sigma_components = element["robust_sigma_components"]
        # strict_sigma_components = element["strict_sigma_components"] 

        markersize = 1
        alpha = 0.2

        true_color = "C0"
        unregulated_color = "C2"
        robust_color = "orange"
        strict_color = "red"

        X_test_sorted = X_test.copy() # Warning: X_test_sorted is not useable as covariate matrix because the columns dont relate to each other after sorting!
        F_test_sorted = F_test.copy()

        mu_components_sorted = mu_components.copy()
        robust_mu_components_sorted = robust_mu_components.copy()
        strict_mu_components_sorted = strict_mu_components.copy()

        # S_test_sorted = S_test
        # sigma_components_sorted = sigma_components
        # robust_sigma_components_sorted = robust_sigma_components
        # strict_sigma_components_sorted = strict_sigma_components


        for variable in range(0,3):

            sorted_indices = np.argsort(X_test[:,variable])
            X_test_sorted[:, variable] = X_test[sorted_indices, variable]
            F_test_sorted[:, variable] = F_test[sorted_indices, variable]
            # S_test_sorted[:, variable] = S_test[sorted_indices, variable]

            mu_components_sorted[:, variable] = mu_components[sorted_indices, variable]
            robust_mu_components_sorted[:, variable] = robust_mu_components[sorted_indices, variable]
            strict_mu_components_sorted[:, variable] = strict_mu_components[sorted_indices, variable]

            # sigma_components_sorted[:, variable] = sigma_components[sorted_indices, variable]
            # robust_sigma_components_sorted[:, variable] = robust_sigma_components[sorted_indices, variable]
            # strict_sigma_components_sorted[:, variable] = strict_sigma_components[sorted_indices, variable]


        for variable in range(0,3):
            axes[variable].plot(X_test_sorted[:,variable], (F_test_sorted[:,variable] - F_test_sorted[:,variable].mean()), color = true_color, markersize = markersize + 2)
            axes[variable].plot(X_test_sorted[:,variable], (mu_components_sorted[:,variable] - mu_components_sorted[:,variable].mean()), color = unregulated_color, markersize = markersize, alpha = alpha)
            axes[variable].plot(X_test_sorted[:,variable], (robust_mu_components_sorted[:,variable] - robust_mu_components_sorted[:,variable].mean()), color = robust_color, markersize = markersize, alpha = alpha)
            axes[variable].plot(X_test_sorted[:,variable], (strict_mu_components_sorted[:,variable] - strict_mu_components_sorted[:,variable].mean()), color = strict_color, markersize = markersize, alpha = alpha)
            axes[variable].set_title("True vs. Estimated Effect of X on Mean of Y")

# %%
plot_mean_effects(simulation_list)

# %%
table = simulation_mse_tables(simulation_list)
table["Mean_MSE_Avg"] * 100
# Out:
#               X1     X2     X3
# mu         1.457  1.088  1.963
# robust_mu  1.152  0.947  1.123
# strict_mu  1.273  0.466  0.752

# %%
import matplotlib.pyplot as plt

def plot_sigma_effects(sim_list):

    fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = [20, 5])

    for element in sim_list:

        X_test = element["X_test"].numpy()
        # F_test = element["F_test"]
        # mu_components = element["mu_components"]
        # robust_mu_components = element["robust_mu_components"]
        # strict_mu_components = element["strict_mu_components"]

        S_test = element["S_test"]
        sigma_components = element["sigma_components"]
        robust_sigma_components = element["robust_sigma_components"]
        strict_sigma_components = element["strict_sigma_components"] 

        markersize = 1
        alpha = 0.2

        true_color = "C0"
        unregulated_color = "C2"
        robust_color = "orange"
        strict_color = "red"

        X_test_sorted = X_test.copy() # Warning: X_test_sorted is not useable as covariate matrix because the columns dont relate to each other after sorting!
        S_test_sorted = S_test.copy()

        sigma_components_sorted = sigma_components.copy()
        robust_sigma_components_sorted = robust_sigma_components.copy()
        strict_sigma_components_sorted = strict_sigma_components.copy()


        for variable in range(0,3):

            sorted_indices = np.argsort(X_test[:,variable])
            X_test_sorted[:, variable] = X_test[sorted_indices, variable]
            S_test_sorted[:, variable] = S_test[sorted_indices, variable]

            sigma_components_sorted[:, variable] = sigma_components[sorted_indices, variable]
            robust_sigma_components_sorted[:, variable] = robust_sigma_components[sorted_indices, variable]
            strict_sigma_components_sorted[:, variable] = strict_sigma_components[sorted_indices, variable]

        for variable in range(0,3):
            axes[variable].plot(X_test_sorted[:,variable], (S_test_sorted[:,variable] - S_test_sorted[:,variable].mean()), color = true_color, markersize = markersize + 2)
            axes[variable].plot(X_test_sorted[:,variable], (sigma_components_sorted[:,variable] - sigma_components_sorted[:,variable].mean()), color = unregulated_color, markersize = markersize, alpha = alpha)
            axes[variable].plot(X_test_sorted[:,variable], (robust_sigma_components_sorted[:,variable] - robust_sigma_components_sorted[:,variable].mean()), color = robust_color, markersize = markersize, alpha = alpha)
            axes[variable].plot(X_test_sorted[:,variable], (strict_sigma_components_sorted[:,variable] - strict_sigma_components_sorted[:,variable].mean()), color = strict_color, markersize = markersize, alpha = alpha)
            axes[variable].set_title("True vs. Estimated Effect of X on SD(Y)")

# %%
plot_sigma_effects(simulation_list)

# %%
table["Sigma_MSE_Avg"] * 100
# Out:
#                  X1     X2     X3
# sigma         3.780  7.453  4.247
# robust_sigma  0.395  0.148  0.386
# strict_sigma  1.187  0.595  0.150

# %% [markdown]
# - Mittelwert der Linien Plotten
# - Aeberhardt Downweighting Proportion ausprobieren
# - Reales Datenbeispiel
